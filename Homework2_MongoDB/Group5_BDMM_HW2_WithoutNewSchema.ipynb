# %% [markdown]
# <font size="8"><b>Homework 2: AirBnB Document Database</b></font>
#
# **Group number:** **`5`**
#
# **Group members:**
#
# <center>
#
# |STUDENT NAME|STUDENT NUMBER|
# |:---:|:---:|
# |Alexandre Gonçalves|20240738|
# |André Silvestre|20240502|
# |Filipa Pereira|20240509|
# |João Henriques|20240499|
# |Umeima Mahomed|20240543|
#
# </center>
#
#
# **The Homework 2 is comprised of two parts:**
# 1. Data modelling (15 points - $37.5\%$).
# 2. Queries to database to answer the questions (25 points - $62.5\%$).

# %% [markdown]
# <p align="center">
#     <!-- AirBnB Logo  -->
#     <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/6/69/Airbnb_Logo_B%C3%A9lo.svg/1280px-Airbnb_Logo_B%C3%A9lo.svg.png" height="100">
#     <br>
#     <!-- Style Text with same style as AirBnB -->
#     <span style="color: #FF5A5F; font-size: 30px; font-weight: bold;">Document Database</span><span style="color: #484848; font-size: 30px; font-weight: bold;"> MongoDB - Group 5</span>
# </p>

# %% [markdown]
# <font size="6"><b>1. Data Modelling</b></font>
#
# <font size="4">Congratulations! You’ve been hired as part of the new Data Engineering and Management team in the AirBNB Business Intelligence department. The company is restructuring due to unsatisfactory performance from the previous teams.
#
# Before leaving, the head of the Data Modelling department highlighted several issues:
#
# **Data Storage**: A lot of data about AirBNB listings is stored in a single document. While this approach has some advantages, it has also caused performance issues. Queries are slow, and the team didn’t apply patterns, which could improve performance by optimizing the data model. Indexes were also not used.
#
# **Reviews Growth**: The number of reviews for AirBNB is growing rapidly. Currently, we overwrite reviews regularly, but the Business Intelligence department will benefit from storing all reviews and analyzing them over time.
#
# **Data Errors**: There are errors in the data collection, such as duplicate data entries and incorrect timestamps for transactions. The new team will need to decide how to fix these issues.
#
# **Your Role**: In your new role, you’ll need to consider how each database query is used, how often it is needed, and its impact on reads and writes. You should update the database schema to optimize for business use cases. Use tools like embedding, linking, indexes, and patterns to improve the data model. You may need to create new fields, documents, or collections. Be sure to document the pattern you’re applying and the reasons behind your decisions, especially when dealing with duplication and risks of outdated data.
#
# **Key tasks include**:
#
# 1. Streamlining the data collection process.
# 2. Cleaning up the data and optimizing what will be returned for each use case.
# 3. Applying the correct patterns to speed up common queries.
# 4. Ensuring departments get accurate and relevant information from the database.
# 5. Sharing the updated data model schema with other departments.
#
# **Good Practices**: [Check Chapter 6, Mastering MongoDB]
#
# 1. All newly created fields should have capitalized names.
# 2. New queries should work with the most up-to-date database version. If you make multiple changes, all queries should still work after the final updates.
# 3. For some queries, you may need to change the database schema.
# 4. When you are applying specific patterns, like polymorphic, subset, or bucket, name them accordingly.
# 5. Document each major transformation using this format:
# *“We applied {transformation name} because {reasoning behind it}. We expect {change/result} based on {observable measure, such as query speed, number of documents returned, index use, etc.}.”*
#
# </font>

# %% [markdown]
# **Data Cleanup and Schema Adjustments:** [9 points in total]
#
# 1) Before working on the queries below, review the data and adjust the schema based on the typical use case described.
#
# **Typical Use Case**: The most common use of the database is to show property listing information to customers. A query retrieves a listing document from the database. Currently, retrieving a listing takes too long. Decide what information should be included in a typical query and optimize the structure accordingly. For example, customers usually only need a sample of reviews, not all reviews (even though all reviews are stored). They also don’t need past transaction data. Update the document schema to fit this use case. This might involve creating new collections or documents.
#
# **Data Cleanup**: Review the data for any errors (such as transactions that don’t belong to the listing) or unnecessary duplication, and clean it up where needed.

# %% [markdown]
# <font size="6"><b>2. Uses for the database</b></font>
#
# <font size="4">Different AirBNB departments require different analytics from our common database.
# Below are the specific questions from various departments:
#
# **Standard Difficulty Questions:** [2 points per question]
#
# 2)	Once a month, we reward hosts with recognition. Select three superhosts with at least two listings that can accommodate more than four people.
#
# 3)	The company considers inevsting into property to rent. Which bed type is most common in listings with a waterfront and a dishwasher in New York?
#
# 4)	We're considering hiring someone to write reviews professionally. Who wrote the longest review in New York?
#
# 5)	To assess the security of different areas, what is the biggest and smallest (price-security deposit) difference per number of visitors at a property?
#
# 6)  Identify areas by whether they are typically used for short breaks, like weekend mini breaks, or whether they are more suitable for long trips. This information support targeted advertising of different customer types. It is not expected to change much over time so we won’t look to update it, we just require current view. What is the average duration of stay (in nights) per type of property per city (you can use the maximum_nights to measure length of stays)? For each property type return the city with the highest and lowest average value.
#
# **Advanced Difficulty Questions (Consider database optimization for these queries):** [3 points per question]
#
# 7)	We are creating a new webpage for hosts when setting up their account. It will list suggested typical amenities. This data will need to be available every time a host registers a property but is not expected to change very much. The starting point for the list will be all unique amenities currently listed in properties (across all documents). Optimise the database for this use case and show how the data should be queried.
#
# 8)	We plan to rtack our reviewers better. We want to create a webpage that shows the top 20 reviewers and the count of the number of reviews of each of these reviewers. This webpage should be kept up to date. It should also have a link to return the number of reviews for a given reviewer ID or Name (show how to query for number of reviews by ID or query quickly).
#
# 9)	For each property we store review scores across different metrics (accuracy, check-in, cleanliness etc). We consider adding more metrics, although there is no clarity on what these will be. We want to be able to easily query the average score across all of these metrics, including any new metrics that might be added without changing the query. Adjust the data model so this can be done and show the query for an example property.
#
# 10)	We aim to have better access to information about transaction, we wish to develop a search engine that can calculate the average value of transactions in a given period of time quickly for a given property.
#
# 11)	We wish to have a summary webpage that displays information about our top destinations. This webpage should display for each of the top 10 cities some basic information about our operations in the area (number of properties by type for example, average price by type) but you can choose the metrics. For each of the top 10 cities it should also provide some basic information about the top 3 properties in each city (price, number of review, whatever you think useful) to show an example of the properties available in the area. We would like to keep this webpage up to date as information changes.
#
# **Database updates:** [2 points per question]
#
# After optimizing the database, show how to complete the following updates. You can create fictional data. Ensure that previous data does not become stale:
#
# 12) Add a new property with a new host in one of the top 10 cities. The host selects the top 10 most common amenities to list.
#
# 13) Add a new review from one of our top 20 reviewers for this new property.
#
# 14) Add a new review metric called 'x_factor' with a score of 10. Show that the average score across all metrics is correctly calculated for this listing, using the previously developed query.

# %% [markdown]
# # Setup
#
# 1. run Jupyter
# 2. run Docker
# 3. create MongoDB container in Command Prompt: make sure you don't have 'leftover' container from previous runs
#
#         docker run --name mongodb -d -e MONGO_INITDB_ROOT_USERNAME=AzureDiamond -e MONGO_INITDB_ROOT_PASSWORD=hunter2 -p 27017:27017 mongo
#
# 4. run Studio3T
#
# 5. create New Connection OR reconnect to existing Connection:
#
#     5.A	In Studio3T create Connection:
#             a.	Press Connection -> New Connection
#             b.	Insert credentials into URI field: mongodb://AzureDiamond:hunter2@localhost:27017
#             c.	Press Test Connection
#             d.	Assign a name to the Connection (top empty line) -> Save
#             e.	Press Connect
#
#     5.B In Studio3T reconnect to Connection:
#             a. press Connect (top left corner)
#             b. choose MongoDB connection  -> press Connect (MongoDB container must be runnning by this time)
#
# 6.	In Studio3T import the Database:
#             a.	Press Import
#             b.	Choose BSON mongodump archive
#             c.	Find your database path
#             d.	Select All file formats and choose the database file ‘sampledata.archive’
#             e.	Press Run: be patient while the database loads
#             f.	Inspect the collections and documents
#
# Done!

# %%
# Python Connector

# !pip install pymongo
# or #!conda install -y pymongo

from datetime import datetime
from pprint import pprint
import time
from bson.objectid import ObjectId

from pymongo import MongoClient

user="AzureDiamond"
password="hunter2"
host="localhost"
port="27017"
protocol="mongodb"

client = MongoClient(f"{protocol}://{user}:{password}@{host}:{port}")

# Database check
db = client.sample_airbnb 
print(f"Database info: {db}\n")
db.name
# Out:
# Database info: Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'sample_airbnb')
# 'sample_airbnb'

# %% [markdown]
# # **Loading and Inspecting database**

# %%
# Collections are inside our Database 'sample_analytics'

collection_list = db.list_collection_names()

print(f"The database contains {len(collection_list)} collections")
print(f"All collections: {collection_list[0:]}")
print(f"Collection {collection_list[0]} contains {db[collection_list[0]].count_documents({})} documents")
# Out:
# The database contains 2 collections
# All collections: ['listingsAndReviews_HW2', 'listingsAndReviews']
# Collection listingsAndReviews_HW2 contains 5555 documents

# %% [markdown]
# [PyMongo documentation](https://pymongo.readthedocs.io/en/stable/api/pymongo/collection.html)

# %% [markdown]
# ---

# %% [markdown]
# ### **💬 Confirm if All **`Reviews`** are in the same collection**

# %%
# 1. Identify if all copies of reviews contain the same data as 'reviews'
import time
from tqdm import tqdm

def compare_reviews_per_document(verbose=True):
    """
    Compares the 'reviews' array with all 'reviews_copy*' arrays for each document in the collection.
    Checks if 'reviews' contains all reviews from the copies on a per-document basis.

    Args:
        verbose (bool): If True, prints detailed results for each document as they are processed.

    Returns:
        dict: Summary of the comparison, including counts of mismatches and execution time.

    Notes:
        - Uses tqdm to display progress and estimate remaining time.
        - Assumes review uniqueness is determined by '_id' field.
        - Handles cases where review arrays might be missing or empty.

    Sources:
        - $setEquals: https://www.mongodb.com/docs/manual/reference/operator/aggregation/setEquals/
        - $map:       https://www.mongodb.com/docs/manual/reference/operator/aggregation/map/
    """
    # Start timing the entire process
    start_time = time.time()

    # Count total documents for tqdm progress bar
    total_docs = db.listingsAndReviews_HW2.count_documents({})
    
    # Pipeline to process each document individually
    pipeline = [
        # Group by _id to process each document separately
        {"$group": {
            "_id": "$_id",
            "reviews": {"$first": "$reviews"},
            "reviews_copy1": {"$first": "$reviews_copy1"},
            "reviews_copy2": {"$first": "$reviews_copy2"},
            "reviews_copy3": {"$first": "$reviews_copy3"},
            "reviews_copy4": {"$first": "$reviews_copy4"}
        }},
        # Project to compare arrays
        {"$project": {
            "_id": 1,
            "reviews_ids": {"$map": {"input": {"$ifNull": ["$reviews", []]}, "in": "$$this._id"}},
            "copy1_ids": {"$map": {"input": {"$ifNull": ["$reviews_copy1", []]}, "in": "$$this._id"}},
            "copy2_ids": {"$map": {"input": {"$ifNull": ["$reviews_copy2", []]}, "in": "$$this._id"}},
            "copy3_ids": {"$map": {"input": {"$ifNull": ["$reviews_copy3", []]}, "in": "$$this._id"}},
            "copy4_ids": {"$map": {"input": {"$ifNull": ["$reviews_copy4", []]}, "in": "$$this._id"}}
        }},
        # Check if all copy IDs are in reviews
        {"$project": {
            "all_copies_in_reviews": {
                "$and": [
                    {"$setEquals": [
                        "$reviews_ids",
                        {"$concatArrays": ["$reviews_ids", "$copy1_ids"]}
                    ]},
                    {"$setEquals": [
                        "$reviews_ids",
                        {"$concatArrays": ["$reviews_ids", "$copy2_ids"]}
                    ]},
                    {"$setEquals": [
                        "$reviews_ids",
                        {"$concatArrays": ["$reviews_ids", "$copy3_ids"]}
                    ]},
                    {"$setEquals": [
                        "$reviews_ids",
                        {"$concatArrays": ["$reviews_ids", "$copy4_ids"]}
                    ]}
                ]
            },
            "reviews_count": {"$size": "$reviews_ids"},
            "copy1_count": {"$size": "$copy1_ids"},
            "copy2_count": {"$size": "$copy2_ids"},
            "copy3_count": {"$size": "$copy3_ids"},
            "copy4_count": {"$size": "$copy4_ids"}
        }}
    ]

    # Execute pipeline and iterate with tqdm
    mismatches = 0
    cursor = db.listingsAndReviews_HW2.aggregate(pipeline)
    
    with tqdm(total=total_docs, desc="Comparing reviews per document") as pbar:
        for doc in cursor:
            doc_id = doc["_id"]
            all_in_reviews = doc["all_copies_in_reviews"]
            counts = {
                "reviews": doc["reviews_count"],
                "copy1": doc["copy1_count"],
                "copy2": doc["copy2_count"],
                "copy3": doc["copy3_count"],
                "copy4": doc["copy4_count"]
            }
            
            if not all_in_reviews:
                mismatches += 1
                if verbose:
                    print(f"\nMismatch found in document _id: {doc_id}")
                    print(f"Review counts: {counts}")
                    print("Not all reviews_copy* are contained in 'reviews'.")
            elif verbose:
                print(f"\nDocument _id: {doc_id} - All reviews_copy* match 'reviews'.")
                print(f"Review counts: {counts}")
            
            pbar.update(1)

    # Calculate total execution time
    execution_time = time.time() - start_time

    # Summary
    summary = {
        "total_documents": total_docs,
        "mismatches_found": mismatches,
        "execution_time_seconds": execution_time
    }
    
    if verbose:
        print("\nSummary:")
        pprint(summary)
    
    return summary

# Run the function
if __name__ == "__main__":
    result = compare_reviews_per_document(verbose=True)
# Out:
# Comparing reviews per document:   0%|          | 0/5555 [00:00<?, ?it/s]
# Document _id: 10006546 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 51, 'copy1': 51, 'copy2': 51, 'copy3': 51, 'copy4': 51}
#
# Document _id: 10009999 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 1001265 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 96, 'copy1': 96, 'copy2': 96, 'copy3': 96, 'copy4': 96}
#
# Document _id: 10021707 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 1, 'copy1': 1, 'copy2': 1, 'copy3': 1, 'copy4': 1}
#
# Document _id: 10030955 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 1003530 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 70, 'copy1': 70, 'copy2': 70, 'copy3': 70, 'copy4': 70}
#
# Document _id: 10038496 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 70, 'copy1': 70, 'copy2': 70, 'copy3': 70, 'copy4': 70}
#
# Document _id: 10047964 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 1, 'copy1': 1, 'copy2': 1, 'copy3': 1, 'copy4': 1}
#
# Document _id: 10051164 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 1, 'copy1': 1, 'copy2': 1, 'copy3': 1, 'copy4': 1}
#
# Document _id: 10057447 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 10057826 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 5, 'copy1': 5, 'copy2': 5, 'copy3': 5, 'copy4': 5}
#
# Document _id: 10059244 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 10059872 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 3, 'copy1': 3, 'copy2': 3, 'copy3': 3, 'copy4': 3}
#
# Document _id: 10066928 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 10069642 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 10082307 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 10082422 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 10083468 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 178, 'copy1': 178, 'copy2': 178, 'copy3': 178, 'copy4': 178}
#
# Document _id: 10084023 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 81, 'copy1': 81, 'copy2': 81, 'copy3': 81, 'copy4': 81}
#
# Document _id: 10091713 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 64, 'copy1': 64, 'copy2': 64, 'copy3': 64, 'copy4': 64}
#
# Document _id: 10092679 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 27, 'copy1': 27, 'copy2': 27, 'copy3': 27, 'copy4': 27}
#
# Document _id: 10096773 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 1, 'copy1': 1, 'copy2': 1, 'copy3': 1, 'copy4': 1}
#
# Document _id: 10108388 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 109, 'copy1': 109, 'copy2': 109, 'copy3': 109, 'copy4': 109}
#
# Document _id: 10109896 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 10112159 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 10115921 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 3, 'copy1': 3, 'copy2': 3, 'copy3': 3, 'copy4': 3}
#
# Document _id: 10116256 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 10116578 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 10117617 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 12, 'copy1': 12, 'copy2': 12, 'copy3': 12, 'copy4': 12}
#
# Document _id: 10120414 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 10133350 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 9, 'copy1': 9, 'copy2': 9, 'copy3': 9, 'copy4': 9}
#
# Document _id: 10133554 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 29, 'copy1': 29, 'copy2': 29, 'copy3': 29, 'copy4': 29}
#
# Document _id: 10138784 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 123, 'copy1': 123, 'copy2': 123, 'copy3': 123, 'copy4': 123}
#
# Document _id: 10140368 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 239, 'copy1': 239, 'copy2': 239, 'copy3': 239, 'copy4': 239}
#
# Document _id: 10141950 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 1, 'copy1': 1, 'copy2': 1, 'copy3': 1, 'copy4': 1}
#
# Document _id: 10166883 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 22, 'copy1': 22, 'copy2': 22, 'copy3': 22, 'copy4': 22}
#
# Document _id: 10166986 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 1, 'copy1': 1, 'copy2': 1, 'copy3': 1, 'copy4': 1}
#
# Document _id: 1016739 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 8, 'copy1': 8, 'copy2': 8, 'copy3': 8, 'copy4': 8}
#
# Document _id: 10184012 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 10186755 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 1019168 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 62, 'copy1': 62, 'copy2': 62, 'copy3': 62, 'copy4': 62}
#
# Document _id: 10199760 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 10201975 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 24, 'copy1': 24, 'copy2': 24, 'copy3': 24, 'copy4': 24}
#
# Document _id: 10209136 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 4, 'copy1': 4, 'copy2': 4, 'copy3': 4, 'copy4': 4}
#
# Document _id: 10213499 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 61, 'copy1': 61, 'copy2': 61, 'copy3': 61, 'copy4': 61}
#
# Document _id: 10215858 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 9, 'copy1': 9, 'copy2': 9, 'copy3': 9, 'copy4': 9}
#
# Document _id: 10220130 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 1022200 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 1, 'copy1': 1, 'copy2': 1, 'copy3': 1, 'copy4': 1}
#
# Document _id: 10227000 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 1, 'copy1': 1, 'copy2': 1, 'copy3': 1, 'copy4': 1}
#
# Document _id: 10228731 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 1, 'copy1': 1, 'copy2': 1, 'copy3': 1, 'copy4': 1}
#
# Document _id: 10233856 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 22, 'copy1': 22, 'copy2': 22, 'copy3': 22, 'copy4': 22}
#
# Document _id: 10240767 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 162, 'copy1': 162, 'copy2': 162, 'copy3': 162, 'copy4': 162}
#
# Document _id: 10264100 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 8, 'copy1': 8, 'copy2': 8, 'copy3': 8, 'copy4': 8}
#
# Document _id: 10266175 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 32, 'copy1': 32, 'copy2': 32, 'copy3': 32, 'copy4': 32}
#
# Document _id: 10267144 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 29, 'copy1': 29, 'copy2': 29, 'copy3': 29, 'copy4': 29}
#
# Document _id: 10269320 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 225, 'copy1': 225, 'copy2': 225, 'copy3': 225, 'copy4': 225}
#
# Document _id: 10280433 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 103, 'copy1': 103, 'copy2': 103, 'copy3': 103, 'copy4': 103}
#
# Document _id: 10295352 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 10299095 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 1, 'copy1': 1, 'copy2': 1, 'copy3': 1, 'copy4': 1}
#
# Document _id: 102995 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 45, 'copy1': 45, 'copy2': 45, 'copy3': 45, 'copy4': 45}
#
# Document _id: 10306879 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 103161 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 117, 'copy1': 117, 'copy2': 117, 'copy3': 117, 'copy4': 117}
#
# Document _id: 10317142 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 32, 'copy1': 32, 'copy2': 32, 'copy3': 32, 'copy4': 32}
#
# Document _id: 10324377 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 10332161 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 2, 'copy1': 2, 'copy2': 2, 'copy3': 2, 'copy4': 2}
#
# Document _id: 10343118 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 145, 'copy1': 145, 'copy2': 145, 'copy3': 145, 'copy4': 145}
#
# Document _id: 10354347 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 1, 'copy1': 1, 'copy2': 1, 'copy3': 1, 'copy4': 1}
#
# Document _id: 10359729 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 1036027 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 71, 'copy1': 71, 'copy2': 71, 'copy3': 71, 'copy4': 71}
#
# Document _id: 10373872 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 1038163 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 135, 'copy1': 135, 'copy2': 135, 'copy3': 135, 'copy4': 135}
#
# Document _id: 10381879 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 9, 'copy1': 9, 'copy2': 9, 'copy3': 9, 'copy4': 9}
#
# Document _id: 10383490 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 1, 'copy1': 1, 'copy2': 1, 'copy3': 1, 'copy4': 1}
#
# Document _id: 10392282 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 99, 'copy1': 99, 'copy2': 99, 'copy3': 99, 'copy4': 99}
#
# Document _id: 10411341 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 32, 'copy1': 32, 'copy2': 32, 'copy3': 32, 'copy4': 32}
#
# Document _id: 10415637 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 11, 'copy1': 11, 'copy2': 11, 'copy3': 11, 'copy4': 11}
#
# Document _id: 10416859 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 104, 'copy1': 104, 'copy2': 104, 'copy3': 104, 'copy4': 104}
#
# Document _id: 10423504 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 139, 'copy1': 139, 'copy2': 139, 'copy3': 139, 'copy4': 139}
#
# Document _id: 1042446 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 19, 'copy1': 19, 'copy2': 19, 'copy3': 19, 'copy4': 19}
#
# Document _id: 10431455 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 10448594 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 13, 'copy1': 13, 'copy2': 13, 'copy3': 13, 'copy4': 13}
#
# Document _id: 10449328 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 10458796 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 179, 'copy1': 179, 'copy2': 179, 'copy3': 179, 'copy4': 179}
#
# Document _id: 10459480 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 1047087 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 146, 'copy1': 146, 'copy2': 146, 'copy3': 146, 'copy4': 146}
#
# Document _id: 10471178 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 10486984 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 77, 'copy1': 77, 'copy2': 77, 'copy3': 77, 'copy4': 77}
#
# Document _id: 10487917 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 31, 'copy1': 31, 'copy2': 31, 'copy3': 31, 'copy4': 31}
#
# Document _id: 10488837 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 10519173 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 18, 'copy1': 18, 'copy2': 18, 'copy3': 18, 'copy4': 18}
#
# Document _id: 10527212 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 18, 'copy1': 18, 'copy2': 18, 'copy3': 18, 'copy4': 18}
#
# Document _id: 10527243 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 65, 'copy1': 65, 'copy2': 65, 'copy3': 65, 'copy4': 65}
#
# Document _id: 10542174 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 1, 'copy1': 1, 'copy2': 1, 'copy3': 1, 'copy4': 1}
#
# Document _id: 10545725 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 1, 'copy1': 1, 'copy2': 1, 'copy3': 1, 'copy4': 1}
#
# Document _id: 10545815 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 126, 'copy1': 126, 'copy2': 126, 'copy3': 126, 'copy4': 126}
#
# Document _id: 10548991 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 45, 'copy1': 45, 'copy2': 45, 'copy3': 45, 'copy4': 45}
#
# Document _id: 10552362 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 2, 'copy1': 2, 'copy2': 2, 'copy3': 2, 'copy4': 2}
#
# Document _id: 10558807 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 51, 'copy1': 51, 'copy2': 51, 'copy3': 51, 'copy4': 51}
#
# Document _id: 10560325 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 20, 'copy1': 20, 'copy2': 20, 'copy3': 20, 'copy4': 20}
#
# Document _id: 10570041 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 9, 'copy1': 9, 'copy2': 9, 'copy3': 9, 'copy4': 9}
#
# Document _id: 10573225 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 115, 'copy1': 115, 'copy2': 115, 'copy3': 115, 'copy4': 115}
# Comparing reviews per document: 100%|██████████| 5555/5555 [00:00<00:00, 10209.85it/s]
# Document _id: 10578580 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 114, 'copy1': 114, 'copy2': 114, 'copy3': 114, 'copy4': 114}
#
# Document _id: 10581101 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 77, 'copy1': 77, 'copy2': 77, 'copy3': 77, 'copy4': 77}
#
# Document _id: 1058555 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 31, 'copy1': 31, 'copy2': 31, 'copy3': 31, 'copy4': 31}
#
# Document _id: 10596036 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 10612199 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 10, 'copy1': 10, 'copy2': 10, 'copy3': 10, 'copy4': 10}
#
# Document _id: 10624493 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 10628126 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 132, 'copy1': 132, 'copy2': 132, 'copy3': 132, 'copy4': 132}
#
# Document _id: 1063491 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 110, 'copy1': 110, 'copy2': 110, 'copy3': 110, 'copy4': 110}
#
# Document _id: 10635276 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 13, 'copy1': 13, 'copy2': 13, 'copy3': 13, 'copy4': 13}
#
# Document _id: 10639317 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 10648267 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 1, 'copy1': 1, 'copy2': 1, 'copy3': 1, 'copy4': 1}
#
# Document _id: 10659534 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 10, 'copy1': 10, 'copy2': 10, 'copy3': 10, 'copy4': 10}
#
# Document _id: 10664888 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 62, 'copy1': 62, 'copy2': 62, 'copy3': 62, 'copy4': 62}
#
# Document _id: 1066648 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 1067052 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 18, 'copy1': 18, 'copy2': 18, 'copy3': 18, 'copy4': 18}
#
# Document _id: 10671783 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 10675315 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 10677883 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 2, 'copy1': 2, 'copy2': 2, 'copy3': 2, 'copy4': 2}
#
# Document _id: 1068505 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 46, 'copy1': 46, 'copy2': 46, 'copy3': 46, 'copy4': 46}
#
# Document _id: 1069531 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 167, 'copy1': 167, 'copy2': 167, 'copy3': 167, 'copy4': 167}
#
# Document _id: 1070322 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 191, 'copy1': 191, 'copy2': 191, 'copy3': 191, 'copy4': 191}
#
# Document _id: 10706900 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 34, 'copy1': 34, 'copy2': 34, 'copy3': 34, 'copy4': 34}
#
# Document _id: 10716793 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 1073607 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 84, 'copy1': 84, 'copy2': 84, 'copy3': 84, 'copy4': 84}
#
# Document _id: 1074008 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 17, 'copy1': 17, 'copy2': 17, 'copy3': 17, 'copy4': 17}
#
# Document _id: 10742116 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 6, 'copy1': 6, 'copy2': 6, 'copy3': 6, 'copy4': 6}
#
# Document _id: 10751153 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 32, 'copy1': 32, 'copy2': 32, 'copy3': 32, 'copy4': 32}
#
# Document _id: 10752737 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 1077686 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 10782351 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 1, 'copy1': 1, 'copy2': 1, 'copy3': 1, 'copy4': 1}
#
# Document _id: 1079887 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 104, 'copy1': 104, 'copy2': 104, 'copy3': 104, 'copy4': 104}
#
# Document _id: 10802909 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 122, 'copy1': 122, 'copy2': 122, 'copy3': 122, 'copy4': 122}
#
# Document _id: 10812136 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 10816768 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 86, 'copy1': 86, 'copy2': 86, 'copy3': 86, 'copy4': 86}
#
# Document _id: 10819035 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 10828339 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 1, 'copy1': 1, 'copy2': 1, 'copy3': 1, 'copy4': 1}
#
# Document _id: 10839801 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 72, 'copy1': 72, 'copy2': 72, 'copy3': 72, 'copy4': 72}
#
# Document _id: 10839973 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 10840938 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 125, 'copy1': 125, 'copy2': 125, 'copy3': 125, 'copy4': 125}
#
# Document _id: 10850008 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 29, 'copy1': 29, 'copy2': 29, 'copy3': 29, 'copy4': 29}
#
# Document _id: 10852990 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 10855800 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 10857454 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 89, 'copy1': 89, 'copy2': 89, 'copy3': 89, 'copy4': 89}
#
# Document _id: 10862541 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 10887852 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 60, 'copy1': 60, 'copy2': 60, 'copy3': 60, 'copy4': 60}
#
# Document _id: 10893326 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 18, 'copy1': 18, 'copy2': 18, 'copy3': 18, 'copy4': 18}
#
# Document _id: 1089542 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 241, 'copy1': 241, 'copy2': 241, 'copy3': 241, 'copy4': 241}
#
# Document _id: 1090153 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 3, 'copy1': 3, 'copy2': 3, 'copy3': 3, 'copy4': 3}
#
# Document _id: 10908640 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 2, 'copy1': 2, 'copy2': 2, 'copy3': 2, 'copy4': 2}
#
# Document _id: 10911771 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 15, 'copy1': 15, 'copy2': 15, 'copy3': 15, 'copy4': 15}
#
# Document _id: 1092760 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 184, 'copy1': 184, 'copy2': 184, 'copy3': 184, 'copy4': 184}
#
# Document _id: 10932304 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 44, 'copy1': 44, 'copy2': 44, 'copy3': 44, 'copy4': 44}
#
# Document _id: 10948197 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 137, 'copy1': 137, 'copy2': 137, 'copy3': 137, 'copy4': 137}
#
# Document _id: 1095174 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 119, 'copy1': 119, 'copy2': 119, 'copy3': 119, 'copy4': 119}
#
# Document _id: 10977704 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 203, 'copy1': 203, 'copy2': 203, 'copy3': 203, 'copy4': 203}
#
# Document _id: 1098211 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 9, 'copy1': 9, 'copy2': 9, 'copy3': 9, 'copy4': 9}
#
# Document _id: 10985735 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 15, 'copy1': 15, 'copy2': 15, 'copy3': 15, 'copy4': 15}
#
# Document _id: 10990260 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 21, 'copy1': 21, 'copy2': 21, 'copy3': 21, 'copy4': 21}
#
# Document _id: 10992286 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 44, 'copy1': 44, 'copy2': 44, 'copy3': 44, 'copy4': 44}
#
# Document _id: 10992671 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 13, 'copy1': 13, 'copy2': 13, 'copy3': 13, 'copy4': 13}
#
# Document _id: 11005300 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 19, 'copy1': 19, 'copy2': 19, 'copy3': 19, 'copy4': 19}
#
# Document _id: 11006512 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 11007058 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 1, 'copy1': 1, 'copy2': 1, 'copy3': 1, 'copy4': 1}
#
# Document _id: 11007542 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 1, 'copy1': 1, 'copy2': 1, 'copy3': 1, 'copy4': 1}
#
# Document _id: 1101035 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 215, 'copy1': 215, 'copy2': 215, 'copy3': 215, 'copy4': 215}
#
# Document _id: 11012484 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 1104768 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 103, 'copy1': 103, 'copy2': 103, 'copy3': 103, 'copy4': 103}
#
# Document _id: 11055163 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 105, 'copy1': 105, 'copy2': 105, 'copy3': 105, 'copy4': 105}
#
# Document _id: 11080033 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 1, 'copy1': 1, 'copy2': 1, 'copy3': 1, 'copy4': 1}
#
# Document _id: 11093339 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 206, 'copy1': 206, 'copy2': 206, 'copy3': 206, 'copy4': 206}
#
# Document _id: 11095139 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 139, 'copy1': 139, 'copy2': 139, 'copy3': 139, 'copy4': 139}
#
# Document _id: 11097962 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 199, 'copy1': 199, 'copy2': 199, 'copy3': 199, 'copy4': 199}
#
# Document _id: 11098708 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 211, 'copy1': 211, 'copy2': 211, 'copy3': 211, 'copy4': 211}
#
# Document _id: 11108923 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 130, 'copy1': 130, 'copy2': 130, 'copy3': 130, 'copy4': 130}
#
# Document _id: 11113983 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 1111410 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 43, 'copy1': 43, 'copy2': 43, 'copy3': 43, 'copy4': 43}
#
# Document _id: 11115528 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 108, 'copy1': 108, 'copy2': 108, 'copy3': 108, 'copy4': 108}
#
# Document _id: 1112838 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 129, 'copy1': 129, 'copy2': 129, 'copy3': 129, 'copy4': 129}
#
# Document _id: 11130156 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 11131495 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 7, 'copy1': 7, 'copy2': 7, 'copy3': 7, 'copy4': 7}
#
# Document _id: 11136898 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 57, 'copy1': 57, 'copy2': 57, 'copy3': 57, 'copy4': 57}
#
# Document _id: 11144250 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 22, 'copy1': 22, 'copy2': 22, 'copy3': 22, 'copy4': 22}
#
# Document _id: 11145180 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 27, 'copy1': 27, 'copy2': 27, 'copy3': 27, 'copy4': 27}
#
# Document _id: 11146498 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 2, 'copy1': 2, 'copy2': 2, 'copy3': 2, 'copy4': 2}
#
# Document _id: 11153910 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 1, 'copy1': 1, 'copy2': 1, 'copy3': 1, 'copy4': 1}
#
# Document _id: 11157167 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 26, 'copy1': 26, 'copy2': 26, 'copy3': 26, 'copy4': 26}
#
# Document _id: 1117706 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 16, 'copy1': 16, 'copy2': 16, 'copy3': 16, 'copy4': 16}
#
# Document _id: 11191242 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 19, 'copy1': 19, 'copy2': 19, 'copy3': 19, 'copy4': 19}
#
# Document _id: 11193311 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 23, 'copy1': 23, 'copy2': 23, 'copy3': 23, 'copy4': 23}
#
# Document _id: 11194486 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 11194788 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 11197217 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 2, 'copy1': 2, 'copy2': 2, 'copy3': 2, 'copy4': 2}
#
# Document _id: 11207193 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 7, 'copy1': 7, 'copy2': 7, 'copy3': 7, 'copy4': 7}
#
# Document _id: 11223389 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 112, 'copy1': 112, 'copy2': 112, 'copy3': 112, 'copy4': 112}
#
# Document _id: 11242147 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 4, 'copy1': 4, 'copy2': 4, 'copy3': 4, 'copy4': 4}
#
# Document _id: 11264406 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 1, 'copy1': 1, 'copy2': 1, 'copy3': 1, 'copy4': 1}
#
# Document _id: 1127954 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 1, 'copy1': 1, 'copy2': 1, 'copy3': 1, 'copy4': 1}
#
# Document _id: 1129061 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 87, 'copy1': 87, 'copy2': 87, 'copy3': 87, 'copy4': 87}
#
# Document _id: 11305966 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 3, 'copy1': 3, 'copy2': 3, 'copy3': 3, 'copy4': 3}
#
# Document _id: 1131054 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 35, 'copy1': 35, 'copy2': 35, 'copy3': 35, 'copy4': 35}
#
# Document _id: 11319047 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 1132409 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 12, 'copy1': 12, 'copy2': 12, 'copy3': 12, 'copy4': 12}
#
# Document _id: 11335874 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 2, 'copy1': 2, 'copy2': 2, 'copy3': 2, 'copy4': 2}
#
# Document _id: 1136399 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 11364106 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 5, 'copy1': 5, 'copy2': 5, 'copy3': 5, 'copy4': 5}
#
# Document _id: 11378656 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 11379251 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 1, 'copy1': 1, 'copy2': 1, 'copy3': 1, 'copy4': 1}
#
# Document _id: 1138483 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 230, 'copy1': 230, 'copy2': 230, 'copy3': 230, 'copy4': 230}
#
# Document _id: 11387183 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 11396243 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 2, 'copy1': 2, 'copy2': 2, 'copy3': 2, 'copy4': 2}
#
# Document _id: 1139810 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 54, 'copy1': 54, 'copy2': 54, 'copy3': 54, 'copy4': 54}
#
# Document _id: 11406680 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 11, 'copy1': 11, 'copy2': 11, 'copy3': 11, 'copy4': 11}
#
# Document _id: 11409841 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 24, 'copy1': 24, 'copy2': 24, 'copy3': 24, 'copy4': 24}
#
# Document _id: 11413023 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 229, 'copy1': 229, 'copy2': 229, 'copy3': 229, 'copy4': 229}
#
# Document _id: 11420459 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 1143151 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 41, 'copy1': 41, 'copy2': 41, 'copy3': 41, 'copy4': 41}
#
# Document _id: 1144090 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 380, 'copy1': 380, 'copy2': 380, 'copy3': 380, 'copy4': 380}
#
# Document _id: 11442936 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 2, 'copy1': 2, 'copy2': 2, 'copy3': 2, 'copy4': 2}
#
# Document _id: 11444539 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 38, 'copy1': 38, 'copy2': 38, 'copy3': 38, 'copy4': 38}
#
# Document _id: 11447743 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 211, 'copy1': 211, 'copy2': 211, 'copy3': 211, 'copy4': 211}
#
# Document _id: 1145567 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 12, 'copy1': 12, 'copy2': 12, 'copy3': 12, 'copy4': 12}
#
# Document _id: 11459525 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 4, 'copy1': 4, 'copy2': 4, 'copy3': 4, 'copy4': 4}
#
# Document _id: 11464859 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 203, 'copy1': 203, 'copy2': 203, 'copy3': 203, 'copy4': 203}
#
# Document _id: 1146653 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 24, 'copy1': 24, 'copy2': 24, 'copy3': 24, 'copy4': 24}
#
# Document _id: 11472884 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 11480835 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 11488558 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 5, 'copy1': 5, 'copy2': 5, 'copy3': 5, 'copy4': 5}
#
# Document _id: 1148978 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 45, 'copy1': 45, 'copy2': 45, 'copy3': 45, 'copy4': 45}
#
# Document _id: 11510109 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 1, 'copy1': 1, 'copy2': 1, 'copy3': 1, 'copy4': 1}
#
# Document _id: 11533406 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 11, 'copy1': 11, 'copy2': 11, 'copy3': 11, 'copy4': 11}
#
# Document _id: 1153834 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 6, 'copy1': 6, 'copy2': 6, 'copy3': 6, 'copy4': 6}
#
# Document _id: 11552866 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 11553333 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 11553357 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 37, 'copy1': 37, 'copy2': 37, 'copy3': 37, 'copy4': 37}
#
# Document _id: 1155475 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 104, 'copy1': 104, 'copy2': 104, 'copy3': 104, 'copy4': 104}
#
# Document _id: 11557363 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 36, 'copy1': 36, 'copy2': 36, 'copy3': 36, 'copy4': 36}
#
# Document _id: 1155885 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 180, 'copy1': 180, 'copy2': 180, 'copy3': 180, 'copy4': 180}
#
# Document _id: 11566403 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 42, 'copy1': 42, 'copy2': 42, 'copy3': 42, 'copy4': 42}
#
# Document _id: 11567179 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 2, 'copy1': 2, 'copy2': 2, 'copy3': 2, 'copy4': 2}
#
# Document _id: 11567815 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 28, 'copy1': 28, 'copy2': 28, 'copy3': 28, 'copy4': 28}
#
# Document _id: 11567997 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 25, 'copy1': 25, 'copy2': 25, 'copy3': 25, 'copy4': 25}
#
# Document _id: 11568230 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 7, 'copy1': 7, 'copy2': 7, 'copy3': 7, 'copy4': 7}
#
# Document _id: 11602050 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 7, 'copy1': 7, 'copy2': 7, 'copy3': 7, 'copy4': 7}
#
# Document _id: 11603201 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 1, 'copy1': 1, 'copy2': 1, 'copy3': 1, 'copy4': 1}
#
# Document _id: 11610598 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 385, 'copy1': 385, 'copy2': 385, 'copy3': 385, 'copy4': 385}
#
# Document _id: 1163119 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 22, 'copy1': 22, 'copy2': 22, 'copy3': 22, 'copy4': 22}
#
# Document _id: 11648362 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 11648810 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 2, 'copy1': 2, 'copy2': 2, 'copy3': 2, 'copy4': 2}
#
# Document _id: 11656239 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 58, 'copy1': 58, 'copy2': 58, 'copy3': 58, 'copy4': 58}
#
# Document _id: 11667313 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 11679012 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 2, 'copy1': 2, 'copy2': 2, 'copy3': 2, 'copy4': 2}
#
# Document _id: 11679106 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 11688660 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 1, 'copy1': 1, 'copy2': 1, 'copy3': 1, 'copy4': 1}
#
# Document _id: 11690230 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 1169088 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 20, 'copy1': 20, 'copy2': 20, 'copy3': 20, 'copy4': 20}
#
# Document _id: 116931 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 122, 'copy1': 122, 'copy2': 122, 'copy3': 122, 'copy4': 122}
#
# Document _id: 11693193 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 94, 'copy1': 94, 'copy2': 94, 'copy3': 94, 'copy4': 94}
#
# Document _id: 11695437 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 33, 'copy1': 33, 'copy2': 33, 'copy3': 33, 'copy4': 33}
#
# Document _id: 11695637 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 11695887 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 17, 'copy1': 17, 'copy2': 17, 'copy3': 17, 'copy4': 17}
#
# Document _id: 11703559 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 163, 'copy1': 163, 'copy2': 163, 'copy3': 163, 'copy4': 163}
#
# Document _id: 11708 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 207, 'copy1': 207, 'copy2': 207, 'copy3': 207, 'copy4': 207}
#
# Document _id: 11715762 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 11716047 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 2, 'copy1': 2, 'copy2': 2, 'copy3': 2, 'copy4': 2}
#
# Document _id: 11719579 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 1, 'copy1': 1, 'copy2': 1, 'copy3': 1, 'copy4': 1}
#
# Document _id: 11727255 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 11737940 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 11740322 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 76, 'copy1': 76, 'copy2': 76, 'copy3': 76, 'copy4': 76}
#
# Document _id: 117425 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 95, 'copy1': 95, 'copy2': 95, 'copy3': 95, 'copy4': 95}
#
# Document _id: 11753116 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 75, 'copy1': 75, 'copy2': 75, 'copy3': 75, 'copy4': 75}
#
# Document _id: 11757719 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 11764681 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 4, 'copy1': 4, 'copy2': 4, 'copy3': 4, 'copy4': 4}
#
# Document _id: 1176693 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 36, 'copy1': 36, 'copy2': 36, 'copy3': 36, 'copy4': 36}
#
# Document _id: 11778475 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 269, 'copy1': 269, 'copy2': 269, 'copy3': 269, 'copy4': 269}
#
# Document _id: 11778959 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 3, 'copy1': 3, 'copy2': 3, 'copy3': 3, 'copy4': 3}
#
# Document _id: 11779701 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 3, 'copy1': 3, 'copy2': 3, 'copy3': 3, 'copy4': 3}
#
# Document _id: 11792238 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 1, 'copy1': 1, 'copy2': 1, 'copy3': 1, 'copy4': 1}
#
# Document _id: 11796483 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 1, 'copy1': 1, 'copy2': 1, 'copy3': 1, 'copy4': 1}
#
# Document _id: 11806776 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 11816864 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 5, 'copy1': 5, 'copy2': 5, 'copy3': 5, 'copy4': 5}
#
# Document _id: 11817249 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 18, 'copy1': 18, 'copy2': 18, 'copy3': 18, 'copy4': 18}
#
# Document _id: 1182474 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 71, 'copy1': 71, 'copy2': 71, 'copy3': 71, 'copy4': 71}
#
# Document _id: 1182475 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 176, 'copy1': 176, 'copy2': 176, 'copy3': 176, 'copy4': 176}
#
# Document _id: 11834359 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 10, 'copy1': 10, 'copy2': 10, 'copy3': 10, 'copy4': 10}
#
# Document _id: 11835169 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 4, 'copy1': 4, 'copy2': 4, 'copy3': 4, 'copy4': 4}
#
# Document _id: 11835516 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 11840338 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 1, 'copy1': 1, 'copy2': 1, 'copy3': 1, 'copy4': 1}
#
# Document _id: 11841749 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 1, 'copy1': 1, 'copy2': 1, 'copy3': 1, 'copy4': 1}
#
# Document _id: 11846549 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 93, 'copy1': 93, 'copy2': 93, 'copy3': 93, 'copy4': 93}
#
# Document _id: 11848397 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 1185644 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 217, 'copy1': 217, 'copy2': 217, 'copy3': 217, 'copy4': 217}
#
# Document _id: 11860047 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 2, 'copy1': 2, 'copy2': 2, 'copy3': 2, 'copy4': 2}
#
# Document _id: 11860692 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 25, 'copy1': 25, 'copy2': 25, 'copy3': 25, 'copy4': 25}
#
# Document _id: 11863943 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 13, 'copy1': 13, 'copy2': 13, 'copy3': 13, 'copy4': 13}
#
# Document _id: 11871088 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 19, 'copy1': 19, 'copy2': 19, 'copy3': 19, 'copy4': 19}
#
# Document _id: 1188839 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 213, 'copy1': 213, 'copy2': 213, 'copy3': 213, 'copy4': 213}
#
# Document _id: 11890476 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 5, 'copy1': 5, 'copy2': 5, 'copy3': 5, 'copy4': 5}
#
# Document _id: 11894971 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 11902059 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 5, 'copy1': 5, 'copy2': 5, 'copy3': 5, 'copy4': 5}
#
# Document _id: 11914814 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 2, 'copy1': 2, 'copy2': 2, 'copy3': 2, 'copy4': 2}
#
# Document _id: 11918738 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 65, 'copy1': 65, 'copy2': 65, 'copy3': 65, 'copy4': 65}
#
# Document _id: 11921637 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 5, 'copy1': 5, 'copy2': 5, 'copy3': 5, 'copy4': 5}
#
# Document _id: 11933497 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 11935301 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 1, 'copy1': 1, 'copy2': 1, 'copy3': 1, 'copy4': 1}
#
# Document _id: 11936451 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 16, 'copy1': 16, 'copy2': 16, 'copy3': 16, 'copy4': 16}
#
# Document _id: 11939367 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 107, 'copy1': 107, 'copy2': 107, 'copy3': 107, 'copy4': 107}
#
# Document _id: 11945972 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 1, 'copy1': 1, 'copy2': 1, 'copy3': 1, 'copy4': 1}
#
# Document _id: 11948645 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 31, 'copy1': 31, 'copy2': 31, 'copy3': 31, 'copy4': 31}
#
# Document _id: 11948705 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 11953606 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 12, 'copy1': 12, 'copy2': 12, 'copy3': 12, 'copy4': 12}
#
# Document _id: 1195977 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 4, 'copy1': 4, 'copy2': 4, 'copy3': 4, 'copy4': 4}
#
# Document _id: 11963985 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 1198074 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 23, 'copy1': 23, 'copy2': 23, 'copy3': 23, 'copy4': 23}
#
# Document _id: 11987001 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 3, 'copy1': 3, 'copy2': 3, 'copy3': 3, 'copy4': 3}
#
# Document _id: 11993586 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 28, 'copy1': 28, 'copy2': 28, 'copy3': 28, 'copy4': 28}
#
# Document _id: 12003707 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 12004365 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 5, 'copy1': 5, 'copy2': 5, 'copy3': 5, 'copy4': 5}
#
# Document _id: 1200438 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 39, 'copy1': 39, 'copy2': 39, 'copy3': 39, 'copy4': 39}
#
# Document _id: 12007662 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 12008712 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 12010910 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 29, 'copy1': 29, 'copy2': 29, 'copy3': 29, 'copy4': 29}
#
# Document _id: 12014026 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 1201871 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 95, 'copy1': 95, 'copy2': 95, 'copy3': 95, 'copy4': 95}
#
# Document _id: 12027124 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 9, 'copy1': 9, 'copy2': 9, 'copy3': 9, 'copy4': 9}
#
# Document _id: 12046370 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 22, 'copy1': 22, 'copy2': 22, 'copy3': 22, 'copy4': 22}
#
# Document _id: 1206363 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 291, 'copy1': 291, 'copy2': 291, 'copy3': 291, 'copy4': 291}
#
# Document _id: 12068078 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 1206820 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 17, 'copy1': 17, 'copy2': 17, 'copy3': 17, 'copy4': 17}
#
# Document _id: 12080961 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 4, 'copy1': 4, 'copy2': 4, 'copy3': 4, 'copy4': 4}
#
# Document _id: 12083780 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 165, 'copy1': 165, 'copy2': 165, 'copy3': 165, 'copy4': 165}
#
# Document _id: 12088301 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 1, 'copy1': 1, 'copy2': 1, 'copy3': 1, 'copy4': 1}
#
# Document _id: 12091894 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 14, 'copy1': 14, 'copy2': 14, 'copy3': 14, 'copy4': 14}
#
# Document _id: 12091977 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 57, 'copy1': 57, 'copy2': 57, 'copy3': 57, 'copy4': 57}
#
# Document _id: 1209353 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 7, 'copy1': 7, 'copy2': 7, 'copy3': 7, 'copy4': 7}
#
# Document _id: 12097507 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 18, 'copy1': 18, 'copy2': 18, 'copy3': 18, 'copy4': 18}
#
# Document _id: 12098138 - All reviews_copy* match 'reviews'.
# ...
# Review counts: {'reviews': 289, 'copy1': 289, 'copy2': 289, 'copy3': 289, 'copy4': 289}
#
# Document _id: 9404853 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 1, 'copy1': 1, 'copy2': 1, 'copy3': 1, 'copy4': 1}
#
# Document _id: 941361 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 351, 'copy1': 351, 'copy2': 351, 'copy3': 351, 'copy4': 351}
#
# Document _id: 9415438 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 1, 'copy1': 1, 'copy2': 1, 'copy3': 1, 'copy4': 1}
#
# Document _id: 9421482 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 14, 'copy1': 14, 'copy2': 14, 'copy3': 14, 'copy4': 14}
#
# Document _id: 9422452 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 39, 'copy1': 39, 'copy2': 39, 'copy3': 39, 'copy4': 39}
#
# Document _id: 9434432 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 9436729 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 9444630 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 52, 'copy1': 52, 'copy2': 52, 'copy3': 52, 'copy4': 52}
#
# Document _id: 944736 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 9448927 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 3, 'copy1': 3, 'copy2': 3, 'copy3': 3, 'copy4': 3}
#
# Document _id: 9451492 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 135, 'copy1': 135, 'copy2': 135, 'copy3': 135, 'copy4': 135}
#
# Document _id: 9473275 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 27, 'copy1': 27, 'copy2': 27, 'copy3': 27, 'copy4': 27}
#
# Document _id: 9485566 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 9493192 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 9497614 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 9498918 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 141, 'copy1': 141, 'copy2': 141, 'copy3': 141, 'copy4': 141}
#
# Document _id: 9504767 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 1, 'copy1': 1, 'copy2': 1, 'copy3': 1, 'copy4': 1}
#
# Document _id: 9505003 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 13, 'copy1': 13, 'copy2': 13, 'copy3': 13, 'copy4': 13}
#
# Document _id: 9511484 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 9516607 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 151, 'copy1': 151, 'copy2': 151, 'copy3': 151, 'copy4': 151}
#
# Document _id: 951837 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 48, 'copy1': 48, 'copy2': 48, 'copy3': 48, 'copy4': 48}
#
# Document _id: 9524926 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 23, 'copy1': 23, 'copy2': 23, 'copy3': 23, 'copy4': 23}
#
# Document _id: 95560 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 463, 'copy1': 463, 'copy2': 463, 'copy3': 463, 'copy4': 463}
#
# Document _id: 9557097 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 66, 'copy1': 66, 'copy2': 66, 'copy3': 66, 'copy4': 66}
#
# Document _id: 9562872 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 77, 'copy1': 77, 'copy2': 77, 'copy3': 77, 'copy4': 77}
#
# Document _id: 9564669 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 9567840 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 165, 'copy1': 165, 'copy2': 165, 'copy3': 165, 'copy4': 165}
#
# Document _id: 9577006 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 33, 'copy1': 33, 'copy2': 33, 'copy3': 33, 'copy4': 33}
#
# Document _id: 9577071 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 4, 'copy1': 4, 'copy2': 4, 'copy3': 4, 'copy4': 4}
#
# Document _id: 9578325 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 103, 'copy1': 103, 'copy2': 103, 'copy3': 103, 'copy4': 103}
#
# Document _id: 9580041 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 1, 'copy1': 1, 'copy2': 1, 'copy3': 1, 'copy4': 1}
#
# Document _id: 958849 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 42, 'copy1': 42, 'copy2': 42, 'copy3': 42, 'copy4': 42}
#
# Document _id: 9589395 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 11, 'copy1': 11, 'copy2': 11, 'copy3': 11, 'copy4': 11}
#
# Document _id: 9590078 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 10, 'copy1': 10, 'copy2': 10, 'copy3': 10, 'copy4': 10}
#
# Document _id: 9590866 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 959349 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 5, 'copy1': 5, 'copy2': 5, 'copy3': 5, 'copy4': 5}
#
# Document _id: 9597872 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 8, 'copy1': 8, 'copy2': 8, 'copy3': 8, 'copy4': 8}
#
# Document _id: 9599384 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 166, 'copy1': 166, 'copy2': 166, 'copy3': 166, 'copy4': 166}
#
# Document _id: 9611825 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 13, 'copy1': 13, 'copy2': 13, 'copy3': 13, 'copy4': 13}
#
# Document _id: 9612902 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 30, 'copy1': 30, 'copy2': 30, 'copy3': 30, 'copy4': 30}
#
# Document _id: 9614181 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 14, 'copy1': 14, 'copy2': 14, 'copy3': 14, 'copy4': 14}
#
# Document _id: 9614672 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 961596 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 18, 'copy1': 18, 'copy2': 18, 'copy3': 18, 'copy4': 18}
#
# Document _id: 9624500 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 9631766 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 9639849 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 1, 'copy1': 1, 'copy2': 1, 'copy3': 1, 'copy4': 1}
#
# Document _id: 9643051 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 29, 'copy1': 29, 'copy2': 29, 'copy3': 29, 'copy4': 29}
#
# Document _id: 9667647 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 1, 'copy1': 1, 'copy2': 1, 'copy3': 1, 'copy4': 1}
#
# Document _id: 9672507 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 13, 'copy1': 13, 'copy2': 13, 'copy3': 13, 'copy4': 13}
#
# Document _id: 967346 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 102, 'copy1': 102, 'copy2': 102, 'copy3': 102, 'copy4': 102}
#
# Document _id: 9677123 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 9686887 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 6, 'copy1': 6, 'copy2': 6, 'copy3': 6, 'copy4': 6}
#
# Document _id: 9688838 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 2, 'copy1': 2, 'copy2': 2, 'copy3': 2, 'copy4': 2}
#
# Document _id: 9691680 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 9696653 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 108, 'copy1': 108, 'copy2': 108, 'copy3': 108, 'copy4': 108}
#
# Document _id: 9698778 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 1, 'copy1': 1, 'copy2': 1, 'copy3': 1, 'copy4': 1}
#
# Document _id: 9701620 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 83, 'copy1': 83, 'copy2': 83, 'copy3': 83, 'copy4': 83}
#
# Document _id: 9703075 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 35, 'copy1': 35, 'copy2': 35, 'copy3': 35, 'copy4': 35}
#
# Document _id: 9708020 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 9712329 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 9714401 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 29, 'copy1': 29, 'copy2': 29, 'copy3': 29, 'copy4': 29}
#
# Document _id: 9721256 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 12, 'copy1': 12, 'copy2': 12, 'copy3': 12, 'copy4': 12}
#
# Document _id: 9733671 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 9735397 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 2, 'copy1': 2, 'copy2': 2, 'copy3': 2, 'copy4': 2}
#
# Document _id: 9736844 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 53, 'copy1': 53, 'copy2': 53, 'copy3': 53, 'copy4': 53}
#
# Document _id: 9738789 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 9740895 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 21, 'copy1': 21, 'copy2': 21, 'copy3': 21, 'copy4': 21}
#
# Document _id: 9744478 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 5, 'copy1': 5, 'copy2': 5, 'copy3': 5, 'copy4': 5}
#
# Document _id: 9746950 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 1, 'copy1': 1, 'copy2': 1, 'copy3': 1, 'copy4': 1}
#
# Document _id: 9755908 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 9759181 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 9759372 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 6, 'copy1': 6, 'copy2': 6, 'copy3': 6, 'copy4': 6}
#
# Document _id: 9762946 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 2, 'copy1': 2, 'copy2': 2, 'copy3': 2, 'copy4': 2}
#
# Document _id: 9765083 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 9767864 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 144, 'copy1': 144, 'copy2': 144, 'copy3': 144, 'copy4': 144}
#
# Document _id: 9774127 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 9789520 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 4, 'copy1': 4, 'copy2': 4, 'copy3': 4, 'copy4': 4}
#
# Document _id: 9794124 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 21, 'copy1': 21, 'copy2': 21, 'copy3': 21, 'copy4': 21}
#
# Document _id: 9795621 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 40, 'copy1': 40, 'copy2': 40, 'copy3': 40, 'copy4': 40}
#
# Document _id: 9796437 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 9799412 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 3, 'copy1': 3, 'copy2': 3, 'copy3': 3, 'copy4': 3}
#
# Document _id: 9802077 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 25, 'copy1': 25, 'copy2': 25, 'copy3': 25, 'copy4': 25}
#
# Document _id: 9807529 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 40, 'copy1': 40, 'copy2': 40, 'copy3': 40, 'copy4': 40}
#
# Document _id: 9807679 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 9810515 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 30, 'copy1': 30, 'copy2': 30, 'copy3': 30, 'copy4': 30}
#
# Document _id: 9815988 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 1, 'copy1': 1, 'copy2': 1, 'copy3': 1, 'copy4': 1}
#
# Document _id: 9834391 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 19, 'copy1': 19, 'copy2': 19, 'copy3': 19, 'copy4': 19}
#
# Document _id: 9834713 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 5, 'copy1': 5, 'copy2': 5, 'copy3': 5, 'copy4': 5}
#
# Document _id: 9846545 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 9848595 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 7, 'copy1': 7, 'copy2': 7, 'copy3': 7, 'copy4': 7}
#
# Document _id: 9848837 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 1, 'copy1': 1, 'copy2': 1, 'copy3': 1, 'copy4': 1}
#
# Document _id: 9849915 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 19, 'copy1': 19, 'copy2': 19, 'copy3': 19, 'copy4': 19}
#
# Document _id: 9853331 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 91, 'copy1': 91, 'copy2': 91, 'copy3': 91, 'copy4': 91}
#
# Document _id: 9867316 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 180, 'copy1': 180, 'copy2': 180, 'copy3': 180, 'copy4': 180}
#
# Document _id: 9887054 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 4, 'copy1': 4, 'copy2': 4, 'copy3': 4, 'copy4': 4}
#
# Document _id: 9895628 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 1, 'copy1': 1, 'copy2': 1, 'copy3': 1, 'copy4': 1}
#
# Document _id: 9907103 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 55, 'copy1': 55, 'copy2': 55, 'copy3': 55, 'copy4': 55}
#
# Document _id: 9907907 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 9908871 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 9917859 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 20, 'copy1': 20, 'copy2': 20, 'copy3': 20, 'copy4': 20}
#
# Document _id: 9936016 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 9937100 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 133, 'copy1': 133, 'copy2': 133, 'copy3': 133, 'copy4': 133}
#
# Document _id: 9944044 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 1, 'copy1': 1, 'copy2': 1, 'copy3': 1, 'copy4': 1}
#
# Document _id: 9951865 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 1, 'copy1': 1, 'copy2': 1, 'copy3': 1, 'copy4': 1}
#
# Document _id: 9969335 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 42, 'copy1': 42, 'copy2': 42, 'copy3': 42, 'copy4': 42}
#
# Document _id: 9979991 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 9981541 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 3, 'copy1': 3, 'copy2': 3, 'copy3': 3, 'copy4': 3}
#
# Document _id: 9983221 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 107, 'copy1': 107, 'copy2': 107, 'copy3': 107, 'copy4': 107}
#
# Document _id: 9985696 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 0, 'copy1': 0, 'copy2': 0, 'copy3': 0, 'copy4': 0}
#
# Document _id: 9987200 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 90, 'copy1': 90, 'copy2': 90, 'copy3': 90, 'copy4': 90}
#
# Document _id: 9990304 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 13, 'copy1': 13, 'copy2': 13, 'copy3': 13, 'copy4': 13}
#
# Document _id: 9993190 - All reviews_copy* match 'reviews'.
# Review counts: {'reviews': 15, 'copy1': 15, 'copy2': 15, 'copy3': 15, 'copy4': 15}
#
# Summary:
# {'execution_time_seconds': 0.6458323001861572,
#  'mismatches_found': 0,
#  'total_documents': 5555}

# %% [markdown]
# #### **Versão "Melhorada"**

# %%
def compare_reviews_per_document(verbose=True):
    """
    Compares the 'reviews' array with all 'reviews_copy*' arrays for each document in the collection.
    Checks if 'reviews' contains all reviews from the copies (by content) on a per-document basis.

    Args:
        verbose (bool): If True, prints detailed results for each document as they are processed.

    Returns:
        dict: Summary of the comparison, including counts of mismatches and execution time.

    Notes:
        - Dynamically detects all fields matching 'reviews_copy*' using $objectToArray.
        - Compares full review content (e.g., _id, date, comments) using $setEquals.
        - Retains counts for additional insight.
        - Uses tqdm for progress tracking.

    Sources:
        - $objectToArray: https://www.mongodb.com/docs/manual/reference/operator/aggregation/objectToArray/
        - $setEquals: https://www.mongodb.com/docs/manual/reference/operator/aggregation/setEquals/
        - $filter: https://www.mongodb.com/docs/manual/reference/operator/aggregation/filter/
    """
    # Start timing the entire process
    start_time = time.time()

    # Count total documents for tqdm progress bar
    total_docs = db.listingsAndReviews_HW2.count_documents({})

    # Pipeline to process each document individually
    pipeline = [
        # Step 1: Group by _id to process each document separately
        {"$group": {
            "_id": "$_id",
            "all_fields": {"$first": "$$ROOT"}  # Keep the entire document
        }},
        # Step 2: Convert document fields to an array to find reviews_copy* dynamically
        {"$project": {
            "_id": 1,
            "reviews": {"$ifNull": ["$all_fields.reviews", []]},
            "copy_fields": {
                "$filter": {  # Filter fields that start with 'reviews_copy'
                    "input": {"$objectToArray": "$all_fields"},
                    "cond": {"$regexMatch": {"input": "$$this.k", "regex": "^reviews_copy"}}
                }
            }
        }},
        # Step 3: Extract and compare content
        {"$project": {
            "reviews_content": "$reviews",  # Full content of reviews
            "copy_contents": {
                "$map": {  # Extract the value (array) from each reviews_copy* field
                    "input": "$copy_fields",
                    "in": {"$ifNull": ["$$this.v", []]}
                }
            },
            "reviews_count": {"$size": {"$ifNull": ["$reviews", []]}},
            "copy_counts": {
                "$map": {  # Count reviews in each copy
                    "input": "$copy_fields",
                    "in": {
                        "name": "$$this.k",
                        "count": {"$size": {"$ifNull": ["$$this.v", []]}}
                    }
                }
            }
        }},
        # Step 4: Compare content and check containment
        {"$project": {
            "all_copies_match_reviews": {
                "$reduce": {  # Iterate over all copy arrays to compare with reviews
                    "input": "$copy_contents",
                    "initialValue": True,
                    "in": {
                        "$and": [
                            "$$value",  # Previous comparison result
                            {"$setEquals": [  # Compare full content
                                "$reviews_content",
                                {"$concatArrays": ["$reviews_content", "$$this"]}
                            ]}
                        ]
                    }
                }
            },
            "reviews_count": 1,
            "copy_counts": 1
        }}
    ]

    # Execute pipeline and iterate with tqdm
    mismatches = 0
    cursor = db.listingsAndReviews_HW2.aggregate(pipeline, allowDiskUse=True)  # Allow disk use for large datasets

    with tqdm(total=total_docs, desc="Comparing reviews per document") as pbar:
        for doc in cursor:
            doc_id = doc["_id"]
            all_match = doc["all_copies_match_reviews"]
            reviews_count = doc["reviews_count"]
            copy_counts = {item["name"]: item["count"] for item in doc["copy_counts"]}

            if not all_match:
                mismatches += 1
                if verbose:
                    print(f"\nMismatch found in document _id: {doc_id}")
                    print(f"Review counts - reviews: {reviews_count}, copies: {copy_counts}")
                    print("Content in 'reviews' does not fully match all 'reviews_copy*' arrays.")
            elif verbose:
                print(f"\nDocument _id: {doc_id} - All 'reviews_copy*' arrays match 'reviews'.")
                print(f"Review counts - reviews: {reviews_count}, copies: {copy_counts}")

            pbar.update(1)

    # Calculate total execution time
    execution_time = time.time() - start_time

    # Summary
    summary = {
        "total_documents": total_docs,
        "mismatches_found": mismatches,
        "execution_time_seconds": execution_time
    }

    if verbose:
        print("\nSummary:")
        pprint(summary)

    return summary

# Run the function
if __name__ == "__main__":
    result = compare_reviews_per_document(verbose=True)
# Out:
# Comparing reviews per document:   0%|          | 0/5555 [00:00<?, ?it/s]
# Document _id: 10006546 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 51, copies: {'reviews_copy1': 51, 'reviews_copy2': 51, 'reviews_copy3': 51, 'reviews_copy4': 51}
#
# Document _id: 10009999 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 1001265 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 96, copies: {'reviews_copy1': 96, 'reviews_copy2': 96, 'reviews_copy3': 96, 'reviews_copy4': 96}
#
# Document _id: 10021707 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 1, copies: {'reviews_copy1': 1, 'reviews_copy2': 1, 'reviews_copy3': 1, 'reviews_copy4': 1}
#
# Document _id: 10030955 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 1003530 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 70, copies: {'reviews_copy1': 70, 'reviews_copy2': 70, 'reviews_copy3': 70, 'reviews_copy4': 70}
#
# Document _id: 10038496 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 70, copies: {'reviews_copy1': 70, 'reviews_copy2': 70, 'reviews_copy3': 70, 'reviews_copy4': 70}
#
# Document _id: 10047964 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 1, copies: {'reviews_copy1': 1, 'reviews_copy2': 1, 'reviews_copy3': 1, 'reviews_copy4': 1}
#
# Document _id: 10051164 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 1, copies: {'reviews_copy1': 1, 'reviews_copy2': 1, 'reviews_copy3': 1, 'reviews_copy4': 1}
#
# Document _id: 10057447 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 10057826 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 5, copies: {'reviews_copy1': 5, 'reviews_copy2': 5, 'reviews_copy3': 5, 'reviews_copy4': 5}
#
# Document _id: 10059244 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 10059872 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 3, copies: {'reviews_copy1': 3, 'reviews_copy2': 3, 'reviews_copy3': 3, 'reviews_copy4': 3}
#
# Document _id: 10066928 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 10069642 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 10082307 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 10082422 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 10083468 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 178, copies: {'reviews_copy1': 178, 'reviews_copy2': 178, 'reviews_copy3': 178, 'reviews_copy4': 178}
#
# Document _id: 10084023 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 81, copies: {'reviews_copy1': 81, 'reviews_copy2': 81, 'reviews_copy3': 81, 'reviews_copy4': 81}
#
# Document _id: 10091713 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 64, copies: {'reviews_copy1': 64, 'reviews_copy2': 64, 'reviews_copy3': 64, 'reviews_copy4': 64}
#
# Document _id: 10092679 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 27, copies: {'reviews_copy1': 27, 'reviews_copy2': 27, 'reviews_copy3': 27, 'reviews_copy4': 27}
#
# Document _id: 10096773 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 1, copies: {'reviews_copy1': 1, 'reviews_copy2': 1, 'reviews_copy3': 1, 'reviews_copy4': 1}
#
# Document _id: 10108388 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 109, copies: {'reviews_copy1': 109, 'reviews_copy2': 109, 'reviews_copy3': 109, 'reviews_copy4': 109}
#
# Document _id: 10109896 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 10112159 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 10115921 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 3, copies: {'reviews_copy1': 3, 'reviews_copy2': 3, 'reviews_copy3': 3, 'reviews_copy4': 3}
#
# Document _id: 10116256 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 10116578 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 10117617 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 12, copies: {'reviews_copy1': 12, 'reviews_copy2': 12, 'reviews_copy3': 12, 'reviews_copy4': 12}
#
# Document _id: 10120414 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 10133350 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 9, copies: {'reviews_copy1': 9, 'reviews_copy2': 9, 'reviews_copy3': 9, 'reviews_copy4': 9}
#
# Document _id: 10133554 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 29, copies: {'reviews_copy1': 29, 'reviews_copy2': 29, 'reviews_copy3': 29, 'reviews_copy4': 29}
#
# Document _id: 10138784 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 123, copies: {'reviews_copy1': 123, 'reviews_copy2': 123, 'reviews_copy3': 123, 'reviews_copy4': 123}
#
# Document _id: 10140368 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 239, copies: {'reviews_copy1': 239, 'reviews_copy2': 239, 'reviews_copy3': 239, 'reviews_copy4': 239}
#
# Document _id: 10141950 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 1, copies: {'reviews_copy1': 1, 'reviews_copy2': 1, 'reviews_copy3': 1, 'reviews_copy4': 1}
#
# Document _id: 10166883 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 22, copies: {'reviews_copy1': 22, 'reviews_copy2': 22, 'reviews_copy3': 22, 'reviews_copy4': 22}
#
# Document _id: 10166986 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 1, copies: {'reviews_copy1': 1, 'reviews_copy2': 1, 'reviews_copy3': 1, 'reviews_copy4': 1}
#
# Document _id: 1016739 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 8, copies: {'reviews_copy1': 8, 'reviews_copy2': 8, 'reviews_copy3': 8, 'reviews_copy4': 8}
#
# Document _id: 10184012 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 10186755 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 1019168 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 62, copies: {'reviews_copy1': 62, 'reviews_copy2': 62, 'reviews_copy3': 62, 'reviews_copy4': 62}
#
# Document _id: 10199760 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 10201975 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 24, copies: {'reviews_copy1': 24, 'reviews_copy2': 24, 'reviews_copy3': 24, 'reviews_copy4': 24}
#
# Document _id: 10209136 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 4, copies: {'reviews_copy1': 4, 'reviews_copy2': 4, 'reviews_copy3': 4, 'reviews_copy4': 4}
#
# Document _id: 10213499 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 61, copies: {'reviews_copy1': 61, 'reviews_copy2': 61, 'reviews_copy3': 61, 'reviews_copy4': 61}
#
# Document _id: 10215858 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 9, copies: {'reviews_copy1': 9, 'reviews_copy2': 9, 'reviews_copy3': 9, 'reviews_copy4': 9}
#
# Document _id: 10220130 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 1022200 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 1, copies: {'reviews_copy1': 1, 'reviews_copy2': 1, 'reviews_copy3': 1, 'reviews_copy4': 1}
#
# Document _id: 10227000 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 1, copies: {'reviews_copy1': 1, 'reviews_copy2': 1, 'reviews_copy3': 1, 'reviews_copy4': 1}
#
# Document _id: 10228731 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 1, copies: {'reviews_copy1': 1, 'reviews_copy2': 1, 'reviews_copy3': 1, 'reviews_copy4': 1}
#
# Document _id: 10233856 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 22, copies: {'reviews_copy1': 22, 'reviews_copy2': 22, 'reviews_copy3': 22, 'reviews_copy4': 22}
#
# Document _id: 10240767 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 162, copies: {'reviews_copy1': 162, 'reviews_copy2': 162, 'reviews_copy3': 162, 'reviews_copy4': 162}
#
# Document _id: 10264100 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 8, copies: {'reviews_copy1': 8, 'reviews_copy2': 8, 'reviews_copy3': 8, 'reviews_copy4': 8}
#
# Document _id: 10266175 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 32, copies: {'reviews_copy1': 32, 'reviews_copy2': 32, 'reviews_copy3': 32, 'reviews_copy4': 32}
#
# Document _id: 10267144 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 29, copies: {'reviews_copy1': 29, 'reviews_copy2': 29, 'reviews_copy3': 29, 'reviews_copy4': 29}
#
# Document _id: 10269320 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 225, copies: {'reviews_copy1': 225, 'reviews_copy2': 225, 'reviews_copy3': 225, 'reviews_copy4': 225}
#
# Document _id: 10280433 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 103, copies: {'reviews_copy1': 103, 'reviews_copy2': 103, 'reviews_copy3': 103, 'reviews_copy4': 103}
#
# Document _id: 10295352 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 10299095 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 1, copies: {'reviews_copy1': 1, 'reviews_copy2': 1, 'reviews_copy3': 1, 'reviews_copy4': 1}
#
# Document _id: 102995 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 45, copies: {'reviews_copy1': 45, 'reviews_copy2': 45, 'reviews_copy3': 45, 'reviews_copy4': 45}
#
# Document _id: 10306879 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 103161 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 117, copies: {'reviews_copy1': 117, 'reviews_copy2': 117, 'reviews_copy3': 117, 'reviews_copy4': 117}
#
# Document _id: 10317142 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 32, copies: {'reviews_copy1': 32, 'reviews_copy2': 32, 'reviews_copy3': 32, 'reviews_copy4': 32}
#
# Document _id: 10324377 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 10332161 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 2, copies: {'reviews_copy1': 2, 'reviews_copy2': 2, 'reviews_copy3': 2, 'reviews_copy4': 2}
#
# Document _id: 10343118 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 145, copies: {'reviews_copy1': 145, 'reviews_copy2': 145, 'reviews_copy3': 145, 'reviews_copy4': 145}
#
# Document _id: 10354347 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 1, copies: {'reviews_copy1': 1, 'reviews_copy2': 1, 'reviews_copy3': 1, 'reviews_copy4': 1}
#
# Document _id: 10359729 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 1036027 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 71, copies: {'reviews_copy1': 71, 'reviews_copy2': 71, 'reviews_copy3': 71, 'reviews_copy4': 71}
#
# Document _id: 10373872 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 1038163 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 135, copies: {'reviews_copy1': 135, 'reviews_copy2': 135, 'reviews_copy3': 135, 'reviews_copy4': 135}
#
# Document _id: 10381879 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 9, copies: {'reviews_copy1': 9, 'reviews_copy2': 9, 'reviews_copy3': 9, 'reviews_copy4': 9}
#
# Document _id: 10383490 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 1, copies: {'reviews_copy1': 1, 'reviews_copy2': 1, 'reviews_copy3': 1, 'reviews_copy4': 1}
#
# Document _id: 10392282 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 99, copies: {'reviews_copy1': 99, 'reviews_copy2': 99, 'reviews_copy3': 99, 'reviews_copy4': 99}
#
# Document _id: 10411341 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 32, copies: {'reviews_copy1': 32, 'reviews_copy2': 32, 'reviews_copy3': 32, 'reviews_copy4': 32}
#
# Document _id: 10415637 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 11, copies: {'reviews_copy1': 11, 'reviews_copy2': 11, 'reviews_copy3': 11, 'reviews_copy4': 11}
#
# Document _id: 10416859 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 104, copies: {'reviews_copy1': 104, 'reviews_copy2': 104, 'reviews_copy3': 104, 'reviews_copy4': 104}
#
# Document _id: 10423504 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 139, copies: {'reviews_copy1': 139, 'reviews_copy2': 139, 'reviews_copy3': 139, 'reviews_copy4': 139}
#
# Document _id: 1042446 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 19, copies: {'reviews_copy1': 19, 'reviews_copy2': 19, 'reviews_copy3': 19, 'reviews_copy4': 19}
#
# Document _id: 10431455 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 10448594 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 13, copies: {'reviews_copy1': 13, 'reviews_copy2': 13, 'reviews_copy3': 13, 'reviews_copy4': 13}
#
# Document _id: 10449328 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 10458796 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 179, copies: {'reviews_copy1': 179, 'reviews_copy2': 179, 'reviews_copy3': 179, 'reviews_copy4': 179}
#
# Document _id: 10459480 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 1047087 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 146, copies: {'reviews_copy1': 146, 'reviews_copy2': 146, 'reviews_copy3': 146, 'reviews_copy4': 146}
#
# Document _id: 10471178 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 10486984 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 77, copies: {'reviews_copy1': 77, 'reviews_copy2': 77, 'reviews_copy3': 77, 'reviews_copy4': 77}
#
# Document _id: 10487917 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 31, copies: {'reviews_copy1': 31, 'reviews_copy2': 31, 'reviews_copy3': 31, 'reviews_copy4': 31}
#
# Document _id: 10488837 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 10519173 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 18, copies: {'reviews_copy1': 18, 'reviews_copy2': 18, 'reviews_copy3': 18, 'reviews_copy4': 18}
#
# Document _id: 10527212 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 18, copies: {'reviews_copy1': 18, 'reviews_copy2': 18, 'reviews_copy3': 18, 'reviews_copy4': 18}
#
# Document _id: 10527243 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 65, copies: {'reviews_copy1': 65, 'reviews_copy2': 65, 'reviews_copy3': 65, 'reviews_copy4': 65}
#
# Document _id: 10542174 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 1, copies: {'reviews_copy1': 1, 'reviews_copy2': 1, 'reviews_copy3': 1, 'reviews_copy4': 1}
#
# Document _id: 10545725 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 1, copies: {'reviews_copy1': 1, 'reviews_copy2': 1, 'reviews_copy3': 1, 'reviews_copy4': 1}
#
# Document _id: 10545815 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 126, copies: {'reviews_copy1': 126, 'reviews_copy2': 126, 'reviews_copy3': 126, 'reviews_copy4': 126}
#
# Document _id: 10548991 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 45, copies: {'reviews_copy1': 45, 'reviews_copy2': 45, 'reviews_copy3': 45, 'reviews_copy4': 45}
#
# Document _id: 10552362 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 2, copies: {'reviews_copy1': 2, 'reviews_copy2': 2, 'reviews_copy3': 2, 'reviews_copy4': 2}
#
# Document _id: 10558807 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 51, copies: {'reviews_copy1': 51, 'reviews_copy2': 51, 'reviews_copy3': 51, 'reviews_copy4': 51}
#
# Document _id: 10560325 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 20, copies: {'reviews_copy1': 20, 'reviews_copy2': 20, 'reviews_copy3': 20, 'reviews_copy4': 20}
#
# Document _id: 10570041 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 9, copies: {'reviews_copy1': 9, 'reviews_copy2': 9, 'reviews_copy3': 9, 'reviews_copy4': 9}
#
# Document _id: 10573225 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 115, copies: {'reviews_copy1': 115, 'reviews_copy2': 115, 'reviews_copy3': 115, 'reviews_copy4': 115}
# Comparing reviews per document: 100%|██████████| 5555/5555 [00:02<00:00, 2343.61it/s]
# Document _id: 10578580 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 114, copies: {'reviews_copy1': 114, 'reviews_copy2': 114, 'reviews_copy3': 114, 'reviews_copy4': 114}
#
# Document _id: 10581101 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 77, copies: {'reviews_copy1': 77, 'reviews_copy2': 77, 'reviews_copy3': 77, 'reviews_copy4': 77}
#
# Document _id: 1058555 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 31, copies: {'reviews_copy1': 31, 'reviews_copy2': 31, 'reviews_copy3': 31, 'reviews_copy4': 31}
#
# Document _id: 10596036 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 10612199 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 10, copies: {'reviews_copy1': 10, 'reviews_copy2': 10, 'reviews_copy3': 10, 'reviews_copy4': 10}
#
# Document _id: 10624493 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 10628126 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 132, copies: {'reviews_copy1': 132, 'reviews_copy2': 132, 'reviews_copy3': 132, 'reviews_copy4': 132}
#
# Document _id: 1063491 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 110, copies: {'reviews_copy1': 110, 'reviews_copy2': 110, 'reviews_copy3': 110, 'reviews_copy4': 110}
#
# Document _id: 10635276 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 13, copies: {'reviews_copy1': 13, 'reviews_copy2': 13, 'reviews_copy3': 13, 'reviews_copy4': 13}
#
# Document _id: 10639317 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 10648267 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 1, copies: {'reviews_copy1': 1, 'reviews_copy2': 1, 'reviews_copy3': 1, 'reviews_copy4': 1}
#
# Document _id: 10659534 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 10, copies: {'reviews_copy1': 10, 'reviews_copy2': 10, 'reviews_copy3': 10, 'reviews_copy4': 10}
#
# Document _id: 10664888 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 62, copies: {'reviews_copy1': 62, 'reviews_copy2': 62, 'reviews_copy3': 62, 'reviews_copy4': 62}
#
# Document _id: 1066648 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 1067052 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 18, copies: {'reviews_copy1': 18, 'reviews_copy2': 18, 'reviews_copy3': 18, 'reviews_copy4': 18}
#
# Document _id: 10671783 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 10675315 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 10677883 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 2, copies: {'reviews_copy1': 2, 'reviews_copy2': 2, 'reviews_copy3': 2, 'reviews_copy4': 2}
#
# Document _id: 1068505 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 46, copies: {'reviews_copy1': 46, 'reviews_copy2': 46, 'reviews_copy3': 46, 'reviews_copy4': 46}
#
# Document _id: 1069531 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 167, copies: {'reviews_copy1': 167, 'reviews_copy2': 167, 'reviews_copy3': 167, 'reviews_copy4': 167}
#
# Document _id: 1070322 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 191, copies: {'reviews_copy1': 191, 'reviews_copy2': 191, 'reviews_copy3': 191, 'reviews_copy4': 191}
#
# Document _id: 10706900 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 34, copies: {'reviews_copy1': 34, 'reviews_copy2': 34, 'reviews_copy3': 34, 'reviews_copy4': 34}
#
# Document _id: 10716793 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 1073607 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 84, copies: {'reviews_copy1': 84, 'reviews_copy2': 84, 'reviews_copy3': 84, 'reviews_copy4': 84}
#
# Document _id: 1074008 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 17, copies: {'reviews_copy1': 17, 'reviews_copy2': 17, 'reviews_copy3': 17, 'reviews_copy4': 17}
#
# Document _id: 10742116 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 6, copies: {'reviews_copy1': 6, 'reviews_copy2': 6, 'reviews_copy3': 6, 'reviews_copy4': 6}
#
# Document _id: 10751153 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 32, copies: {'reviews_copy1': 32, 'reviews_copy2': 32, 'reviews_copy3': 32, 'reviews_copy4': 32}
#
# Document _id: 10752737 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 1077686 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 10782351 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 1, copies: {'reviews_copy1': 1, 'reviews_copy2': 1, 'reviews_copy3': 1, 'reviews_copy4': 1}
#
# Document _id: 1079887 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 104, copies: {'reviews_copy1': 104, 'reviews_copy2': 104, 'reviews_copy3': 104, 'reviews_copy4': 104}
#
# Document _id: 10802909 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 122, copies: {'reviews_copy1': 122, 'reviews_copy2': 122, 'reviews_copy3': 122, 'reviews_copy4': 122}
#
# Document _id: 10812136 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 10816768 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 86, copies: {'reviews_copy1': 86, 'reviews_copy2': 86, 'reviews_copy3': 86, 'reviews_copy4': 86}
#
# Document _id: 10819035 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 10828339 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 1, copies: {'reviews_copy1': 1, 'reviews_copy2': 1, 'reviews_copy3': 1, 'reviews_copy4': 1}
#
# Document _id: 10839801 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 72, copies: {'reviews_copy1': 72, 'reviews_copy2': 72, 'reviews_copy3': 72, 'reviews_copy4': 72}
#
# Document _id: 10839973 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 10840938 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 125, copies: {'reviews_copy1': 125, 'reviews_copy2': 125, 'reviews_copy3': 125, 'reviews_copy4': 125}
#
# Document _id: 10850008 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 29, copies: {'reviews_copy1': 29, 'reviews_copy2': 29, 'reviews_copy3': 29, 'reviews_copy4': 29}
#
# Document _id: 10852990 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 10855800 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 10857454 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 89, copies: {'reviews_copy1': 89, 'reviews_copy2': 89, 'reviews_copy3': 89, 'reviews_copy4': 89}
#
# Document _id: 10862541 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 10887852 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 60, copies: {'reviews_copy1': 60, 'reviews_copy2': 60, 'reviews_copy3': 60, 'reviews_copy4': 60}
#
# Document _id: 10893326 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 18, copies: {'reviews_copy1': 18, 'reviews_copy2': 18, 'reviews_copy3': 18, 'reviews_copy4': 18}
#
# Document _id: 1089542 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 241, copies: {'reviews_copy1': 241, 'reviews_copy2': 241, 'reviews_copy3': 241, 'reviews_copy4': 241}
#
# Document _id: 1090153 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 3, copies: {'reviews_copy1': 3, 'reviews_copy2': 3, 'reviews_copy3': 3, 'reviews_copy4': 3}
#
# Document _id: 10908640 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 2, copies: {'reviews_copy1': 2, 'reviews_copy2': 2, 'reviews_copy3': 2, 'reviews_copy4': 2}
#
# Document _id: 10911771 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 15, copies: {'reviews_copy1': 15, 'reviews_copy2': 15, 'reviews_copy3': 15, 'reviews_copy4': 15}
#
# Document _id: 1092760 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 184, copies: {'reviews_copy1': 184, 'reviews_copy2': 184, 'reviews_copy3': 184, 'reviews_copy4': 184}
#
# Document _id: 10932304 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 44, copies: {'reviews_copy1': 44, 'reviews_copy2': 44, 'reviews_copy3': 44, 'reviews_copy4': 44}
#
# Document _id: 10948197 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 137, copies: {'reviews_copy1': 137, 'reviews_copy2': 137, 'reviews_copy3': 137, 'reviews_copy4': 137}
#
# Document _id: 1095174 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 119, copies: {'reviews_copy1': 119, 'reviews_copy2': 119, 'reviews_copy3': 119, 'reviews_copy4': 119}
#
# Document _id: 10977704 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 203, copies: {'reviews_copy1': 203, 'reviews_copy2': 203, 'reviews_copy3': 203, 'reviews_copy4': 203}
#
# Document _id: 1098211 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 9, copies: {'reviews_copy1': 9, 'reviews_copy2': 9, 'reviews_copy3': 9, 'reviews_copy4': 9}
#
# Document _id: 10985735 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 15, copies: {'reviews_copy1': 15, 'reviews_copy2': 15, 'reviews_copy3': 15, 'reviews_copy4': 15}
#
# Document _id: 10990260 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 21, copies: {'reviews_copy1': 21, 'reviews_copy2': 21, 'reviews_copy3': 21, 'reviews_copy4': 21}
#
# Document _id: 10992286 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 44, copies: {'reviews_copy1': 44, 'reviews_copy2': 44, 'reviews_copy3': 44, 'reviews_copy4': 44}
#
# Document _id: 10992671 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 13, copies: {'reviews_copy1': 13, 'reviews_copy2': 13, 'reviews_copy3': 13, 'reviews_copy4': 13}
#
# Document _id: 11005300 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 19, copies: {'reviews_copy1': 19, 'reviews_copy2': 19, 'reviews_copy3': 19, 'reviews_copy4': 19}
#
# Document _id: 11006512 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 11007058 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 1, copies: {'reviews_copy1': 1, 'reviews_copy2': 1, 'reviews_copy3': 1, 'reviews_copy4': 1}
#
# Document _id: 11007542 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 1, copies: {'reviews_copy1': 1, 'reviews_copy2': 1, 'reviews_copy3': 1, 'reviews_copy4': 1}
#
# Document _id: 1101035 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 215, copies: {'reviews_copy1': 215, 'reviews_copy2': 215, 'reviews_copy3': 215, 'reviews_copy4': 215}
#
# Document _id: 11012484 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 1104768 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 103, copies: {'reviews_copy1': 103, 'reviews_copy2': 103, 'reviews_copy3': 103, 'reviews_copy4': 103}
#
# Document _id: 11055163 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 105, copies: {'reviews_copy1': 105, 'reviews_copy2': 105, 'reviews_copy3': 105, 'reviews_copy4': 105}
#
# Document _id: 11080033 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 1, copies: {'reviews_copy1': 1, 'reviews_copy2': 1, 'reviews_copy3': 1, 'reviews_copy4': 1}
#
# Document _id: 11093339 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 206, copies: {'reviews_copy1': 206, 'reviews_copy2': 206, 'reviews_copy3': 206, 'reviews_copy4': 206}
#
# Document _id: 11095139 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 139, copies: {'reviews_copy1': 139, 'reviews_copy2': 139, 'reviews_copy3': 139, 'reviews_copy4': 139}
#
# Document _id: 11097962 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 199, copies: {'reviews_copy1': 199, 'reviews_copy2': 199, 'reviews_copy3': 199, 'reviews_copy4': 199}
#
# Document _id: 11098708 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 211, copies: {'reviews_copy1': 211, 'reviews_copy2': 211, 'reviews_copy3': 211, 'reviews_copy4': 211}
#
# Document _id: 11108923 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 130, copies: {'reviews_copy1': 130, 'reviews_copy2': 130, 'reviews_copy3': 130, 'reviews_copy4': 130}
#
# Document _id: 11113983 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 1111410 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 43, copies: {'reviews_copy1': 43, 'reviews_copy2': 43, 'reviews_copy3': 43, 'reviews_copy4': 43}
#
# Document _id: 11115528 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 108, copies: {'reviews_copy1': 108, 'reviews_copy2': 108, 'reviews_copy3': 108, 'reviews_copy4': 108}
#
# Document _id: 1112838 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 129, copies: {'reviews_copy1': 129, 'reviews_copy2': 129, 'reviews_copy3': 129, 'reviews_copy4': 129}
#
# Document _id: 11130156 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 11131495 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 7, copies: {'reviews_copy1': 7, 'reviews_copy2': 7, 'reviews_copy3': 7, 'reviews_copy4': 7}
#
# Document _id: 11136898 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 57, copies: {'reviews_copy1': 57, 'reviews_copy2': 57, 'reviews_copy3': 57, 'reviews_copy4': 57}
#
# Document _id: 11144250 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 22, copies: {'reviews_copy1': 22, 'reviews_copy2': 22, 'reviews_copy3': 22, 'reviews_copy4': 22}
#
# Document _id: 11145180 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 27, copies: {'reviews_copy1': 27, 'reviews_copy2': 27, 'reviews_copy3': 27, 'reviews_copy4': 27}
#
# Document _id: 11146498 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 2, copies: {'reviews_copy1': 2, 'reviews_copy2': 2, 'reviews_copy3': 2, 'reviews_copy4': 2}
#
# Document _id: 11153910 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 1, copies: {'reviews_copy1': 1, 'reviews_copy2': 1, 'reviews_copy3': 1, 'reviews_copy4': 1}
#
# Document _id: 11157167 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 26, copies: {'reviews_copy1': 26, 'reviews_copy2': 26, 'reviews_copy3': 26, 'reviews_copy4': 26}
#
# Document _id: 1117706 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 16, copies: {'reviews_copy1': 16, 'reviews_copy2': 16, 'reviews_copy3': 16, 'reviews_copy4': 16}
#
# Document _id: 11191242 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 19, copies: {'reviews_copy1': 19, 'reviews_copy2': 19, 'reviews_copy3': 19, 'reviews_copy4': 19}
#
# Document _id: 11193311 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 23, copies: {'reviews_copy1': 23, 'reviews_copy2': 23, 'reviews_copy3': 23, 'reviews_copy4': 23}
#
# Document _id: 11194486 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 11194788 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 11197217 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 2, copies: {'reviews_copy1': 2, 'reviews_copy2': 2, 'reviews_copy3': 2, 'reviews_copy4': 2}
#
# Document _id: 11207193 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 7, copies: {'reviews_copy1': 7, 'reviews_copy2': 7, 'reviews_copy3': 7, 'reviews_copy4': 7}
#
# Document _id: 11223389 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 112, copies: {'reviews_copy1': 112, 'reviews_copy2': 112, 'reviews_copy3': 112, 'reviews_copy4': 112}
#
# Document _id: 11242147 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 4, copies: {'reviews_copy1': 4, 'reviews_copy2': 4, 'reviews_copy3': 4, 'reviews_copy4': 4}
#
# Document _id: 11264406 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 1, copies: {'reviews_copy1': 1, 'reviews_copy2': 1, 'reviews_copy3': 1, 'reviews_copy4': 1}
#
# Document _id: 1127954 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 1, copies: {'reviews_copy1': 1, 'reviews_copy2': 1, 'reviews_copy3': 1, 'reviews_copy4': 1}
#
# Document _id: 1129061 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 87, copies: {'reviews_copy1': 87, 'reviews_copy2': 87, 'reviews_copy3': 87, 'reviews_copy4': 87}
#
# Document _id: 11305966 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 3, copies: {'reviews_copy1': 3, 'reviews_copy2': 3, 'reviews_copy3': 3, 'reviews_copy4': 3}
#
# Document _id: 1131054 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 35, copies: {'reviews_copy1': 35, 'reviews_copy2': 35, 'reviews_copy3': 35, 'reviews_copy4': 35}
#
# Document _id: 11319047 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 1132409 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 12, copies: {'reviews_copy1': 12, 'reviews_copy2': 12, 'reviews_copy3': 12, 'reviews_copy4': 12}
#
# Document _id: 11335874 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 2, copies: {'reviews_copy1': 2, 'reviews_copy2': 2, 'reviews_copy3': 2, 'reviews_copy4': 2}
#
# Document _id: 1136399 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 11364106 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 5, copies: {'reviews_copy1': 5, 'reviews_copy2': 5, 'reviews_copy3': 5, 'reviews_copy4': 5}
#
# Document _id: 11378656 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 11379251 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 1, copies: {'reviews_copy1': 1, 'reviews_copy2': 1, 'reviews_copy3': 1, 'reviews_copy4': 1}
#
# Document _id: 1138483 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 230, copies: {'reviews_copy1': 230, 'reviews_copy2': 230, 'reviews_copy3': 230, 'reviews_copy4': 230}
#
# Document _id: 11387183 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 11396243 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 2, copies: {'reviews_copy1': 2, 'reviews_copy2': 2, 'reviews_copy3': 2, 'reviews_copy4': 2}
#
# Document _id: 1139810 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 54, copies: {'reviews_copy1': 54, 'reviews_copy2': 54, 'reviews_copy3': 54, 'reviews_copy4': 54}
#
# Document _id: 11406680 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 11, copies: {'reviews_copy1': 11, 'reviews_copy2': 11, 'reviews_copy3': 11, 'reviews_copy4': 11}
#
# Document _id: 11409841 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 24, copies: {'reviews_copy1': 24, 'reviews_copy2': 24, 'reviews_copy3': 24, 'reviews_copy4': 24}
#
# Document _id: 11413023 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 229, copies: {'reviews_copy1': 229, 'reviews_copy2': 229, 'reviews_copy3': 229, 'reviews_copy4': 229}
#
# Document _id: 11420459 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 1143151 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 41, copies: {'reviews_copy1': 41, 'reviews_copy2': 41, 'reviews_copy3': 41, 'reviews_copy4': 41}
#
# Document _id: 1144090 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 380, copies: {'reviews_copy1': 380, 'reviews_copy2': 380, 'reviews_copy3': 380, 'reviews_copy4': 380}
#
# Document _id: 11442936 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 2, copies: {'reviews_copy1': 2, 'reviews_copy2': 2, 'reviews_copy3': 2, 'reviews_copy4': 2}
#
# Document _id: 11444539 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 38, copies: {'reviews_copy1': 38, 'reviews_copy2': 38, 'reviews_copy3': 38, 'reviews_copy4': 38}
#
# Document _id: 11447743 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 211, copies: {'reviews_copy1': 211, 'reviews_copy2': 211, 'reviews_copy3': 211, 'reviews_copy4': 211}
#
# Document _id: 1145567 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 12, copies: {'reviews_copy1': 12, 'reviews_copy2': 12, 'reviews_copy3': 12, 'reviews_copy4': 12}
#
# Document _id: 11459525 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 4, copies: {'reviews_copy1': 4, 'reviews_copy2': 4, 'reviews_copy3': 4, 'reviews_copy4': 4}
#
# Document _id: 11464859 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 203, copies: {'reviews_copy1': 203, 'reviews_copy2': 203, 'reviews_copy3': 203, 'reviews_copy4': 203}
#
# Document _id: 1146653 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 24, copies: {'reviews_copy1': 24, 'reviews_copy2': 24, 'reviews_copy3': 24, 'reviews_copy4': 24}
#
# Document _id: 11472884 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 11480835 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 11488558 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 5, copies: {'reviews_copy1': 5, 'reviews_copy2': 5, 'reviews_copy3': 5, 'reviews_copy4': 5}
#
# Document _id: 1148978 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 45, copies: {'reviews_copy1': 45, 'reviews_copy2': 45, 'reviews_copy3': 45, 'reviews_copy4': 45}
#
# Document _id: 11510109 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 1, copies: {'reviews_copy1': 1, 'reviews_copy2': 1, 'reviews_copy3': 1, 'reviews_copy4': 1}
#
# Document _id: 11533406 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 11, copies: {'reviews_copy1': 11, 'reviews_copy2': 11, 'reviews_copy3': 11, 'reviews_copy4': 11}
#
# Document _id: 1153834 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 6, copies: {'reviews_copy1': 6, 'reviews_copy2': 6, 'reviews_copy3': 6, 'reviews_copy4': 6}
#
# Document _id: 11552866 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 11553333 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 11553357 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 37, copies: {'reviews_copy1': 37, 'reviews_copy2': 37, 'reviews_copy3': 37, 'reviews_copy4': 37}
#
# Document _id: 1155475 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 104, copies: {'reviews_copy1': 104, 'reviews_copy2': 104, 'reviews_copy3': 104, 'reviews_copy4': 104}
#
# Document _id: 11557363 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 36, copies: {'reviews_copy1': 36, 'reviews_copy2': 36, 'reviews_copy3': 36, 'reviews_copy4': 36}
#
# Document _id: 1155885 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 180, copies: {'reviews_copy1': 180, 'reviews_copy2': 180, 'reviews_copy3': 180, 'reviews_copy4': 180}
#
# Document _id: 11566403 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 42, copies: {'reviews_copy1': 42, 'reviews_copy2': 42, 'reviews_copy3': 42, 'reviews_copy4': 42}
#
# Document _id: 11567179 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 2, copies: {'reviews_copy1': 2, 'reviews_copy2': 2, 'reviews_copy3': 2, 'reviews_copy4': 2}
#
# Document _id: 11567815 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 28, copies: {'reviews_copy1': 28, 'reviews_copy2': 28, 'reviews_copy3': 28, 'reviews_copy4': 28}
#
# Document _id: 11567997 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 25, copies: {'reviews_copy1': 25, 'reviews_copy2': 25, 'reviews_copy3': 25, 'reviews_copy4': 25}
#
# Document _id: 11568230 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 7, copies: {'reviews_copy1': 7, 'reviews_copy2': 7, 'reviews_copy3': 7, 'reviews_copy4': 7}
#
# Document _id: 11602050 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 7, copies: {'reviews_copy1': 7, 'reviews_copy2': 7, 'reviews_copy3': 7, 'reviews_copy4': 7}
#
# Document _id: 11603201 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 1, copies: {'reviews_copy1': 1, 'reviews_copy2': 1, 'reviews_copy3': 1, 'reviews_copy4': 1}
#
# Document _id: 11610598 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 385, copies: {'reviews_copy1': 385, 'reviews_copy2': 385, 'reviews_copy3': 385, 'reviews_copy4': 385}
#
# Document _id: 1163119 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 22, copies: {'reviews_copy1': 22, 'reviews_copy2': 22, 'reviews_copy3': 22, 'reviews_copy4': 22}
#
# Document _id: 11648362 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 11648810 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 2, copies: {'reviews_copy1': 2, 'reviews_copy2': 2, 'reviews_copy3': 2, 'reviews_copy4': 2}
#
# Document _id: 11656239 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 58, copies: {'reviews_copy1': 58, 'reviews_copy2': 58, 'reviews_copy3': 58, 'reviews_copy4': 58}
#
# Document _id: 11667313 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# ...
#
# Document _id: 9577071 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 4, copies: {'reviews_copy1': 4, 'reviews_copy2': 4, 'reviews_copy3': 4, 'reviews_copy4': 4}
#
# Document _id: 9578325 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 103, copies: {'reviews_copy1': 103, 'reviews_copy2': 103, 'reviews_copy3': 103, 'reviews_copy4': 103}
#
# Document _id: 9580041 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 1, copies: {'reviews_copy1': 1, 'reviews_copy2': 1, 'reviews_copy3': 1, 'reviews_copy4': 1}
#
# Document _id: 958849 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 42, copies: {'reviews_copy1': 42, 'reviews_copy2': 42, 'reviews_copy3': 42, 'reviews_copy4': 42}
#
# Document _id: 9589395 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 11, copies: {'reviews_copy1': 11, 'reviews_copy2': 11, 'reviews_copy3': 11, 'reviews_copy4': 11}
#
# Document _id: 9590078 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 10, copies: {'reviews_copy1': 10, 'reviews_copy2': 10, 'reviews_copy3': 10, 'reviews_copy4': 10}
#
# Document _id: 9590866 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 959349 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 5, copies: {'reviews_copy1': 5, 'reviews_copy2': 5, 'reviews_copy3': 5, 'reviews_copy4': 5}
#
# Document _id: 9597872 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 8, copies: {'reviews_copy1': 8, 'reviews_copy2': 8, 'reviews_copy3': 8, 'reviews_copy4': 8}
#
# Document _id: 9599384 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 166, copies: {'reviews_copy1': 166, 'reviews_copy2': 166, 'reviews_copy3': 166, 'reviews_copy4': 166}
#
# Document _id: 9611825 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 13, copies: {'reviews_copy1': 13, 'reviews_copy2': 13, 'reviews_copy3': 13, 'reviews_copy4': 13}
#
# Document _id: 9612902 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 30, copies: {'reviews_copy1': 30, 'reviews_copy2': 30, 'reviews_copy3': 30, 'reviews_copy4': 30}
#
# Document _id: 9614181 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 14, copies: {'reviews_copy1': 14, 'reviews_copy2': 14, 'reviews_copy3': 14, 'reviews_copy4': 14}
#
# Document _id: 9614672 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 961596 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 18, copies: {'reviews_copy1': 18, 'reviews_copy2': 18, 'reviews_copy3': 18, 'reviews_copy4': 18}
#
# Document _id: 9624500 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 9631766 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 9639849 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 1, copies: {'reviews_copy1': 1, 'reviews_copy2': 1, 'reviews_copy3': 1, 'reviews_copy4': 1}
#
# Document _id: 9643051 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 29, copies: {'reviews_copy1': 29, 'reviews_copy2': 29, 'reviews_copy3': 29, 'reviews_copy4': 29}
#
# Document _id: 9667647 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 1, copies: {'reviews_copy1': 1, 'reviews_copy2': 1, 'reviews_copy3': 1, 'reviews_copy4': 1}
#
# Document _id: 9672507 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 13, copies: {'reviews_copy1': 13, 'reviews_copy2': 13, 'reviews_copy3': 13, 'reviews_copy4': 13}
#
# Document _id: 967346 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 102, copies: {'reviews_copy1': 102, 'reviews_copy2': 102, 'reviews_copy3': 102, 'reviews_copy4': 102}
#
# Document _id: 9677123 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 9686887 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 6, copies: {'reviews_copy1': 6, 'reviews_copy2': 6, 'reviews_copy3': 6, 'reviews_copy4': 6}
#
# Document _id: 9688838 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 2, copies: {'reviews_copy1': 2, 'reviews_copy2': 2, 'reviews_copy3': 2, 'reviews_copy4': 2}
#
# Document _id: 9691680 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 9696653 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 108, copies: {'reviews_copy1': 108, 'reviews_copy2': 108, 'reviews_copy3': 108, 'reviews_copy4': 108}
#
# Document _id: 9698778 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 1, copies: {'reviews_copy1': 1, 'reviews_copy2': 1, 'reviews_copy3': 1, 'reviews_copy4': 1}
#
# Document _id: 9701620 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 83, copies: {'reviews_copy1': 83, 'reviews_copy2': 83, 'reviews_copy3': 83, 'reviews_copy4': 83}
#
# Document _id: 9703075 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 35, copies: {'reviews_copy1': 35, 'reviews_copy2': 35, 'reviews_copy3': 35, 'reviews_copy4': 35}
#
# Document _id: 9708020 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 9712329 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 9714401 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 29, copies: {'reviews_copy1': 29, 'reviews_copy2': 29, 'reviews_copy3': 29, 'reviews_copy4': 29}
#
# Document _id: 9721256 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 12, copies: {'reviews_copy1': 12, 'reviews_copy2': 12, 'reviews_copy3': 12, 'reviews_copy4': 12}
#
# Document _id: 9733671 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 9735397 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 2, copies: {'reviews_copy1': 2, 'reviews_copy2': 2, 'reviews_copy3': 2, 'reviews_copy4': 2}
#
# Document _id: 9736844 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 53, copies: {'reviews_copy1': 53, 'reviews_copy2': 53, 'reviews_copy3': 53, 'reviews_copy4': 53}
#
# Document _id: 9738789 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 9740895 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 21, copies: {'reviews_copy1': 21, 'reviews_copy2': 21, 'reviews_copy3': 21, 'reviews_copy4': 21}
#
# Document _id: 9744478 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 5, copies: {'reviews_copy1': 5, 'reviews_copy2': 5, 'reviews_copy3': 5, 'reviews_copy4': 5}
#
# Document _id: 9746950 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 1, copies: {'reviews_copy1': 1, 'reviews_copy2': 1, 'reviews_copy3': 1, 'reviews_copy4': 1}
#
# Document _id: 9755908 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 9759181 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 9759372 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 6, copies: {'reviews_copy1': 6, 'reviews_copy2': 6, 'reviews_copy3': 6, 'reviews_copy4': 6}
#
# Document _id: 9762946 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 2, copies: {'reviews_copy1': 2, 'reviews_copy2': 2, 'reviews_copy3': 2, 'reviews_copy4': 2}
#
# Document _id: 9765083 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 9767864 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 144, copies: {'reviews_copy1': 144, 'reviews_copy2': 144, 'reviews_copy3': 144, 'reviews_copy4': 144}
#
# Document _id: 9774127 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 9789520 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 4, copies: {'reviews_copy1': 4, 'reviews_copy2': 4, 'reviews_copy3': 4, 'reviews_copy4': 4}
#
# Document _id: 9794124 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 21, copies: {'reviews_copy1': 21, 'reviews_copy2': 21, 'reviews_copy3': 21, 'reviews_copy4': 21}
#
# Document _id: 9795621 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 40, copies: {'reviews_copy1': 40, 'reviews_copy2': 40, 'reviews_copy3': 40, 'reviews_copy4': 40}
#
# Document _id: 9796437 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 9799412 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 3, copies: {'reviews_copy1': 3, 'reviews_copy2': 3, 'reviews_copy3': 3, 'reviews_copy4': 3}
#
# Document _id: 9802077 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 25, copies: {'reviews_copy1': 25, 'reviews_copy2': 25, 'reviews_copy3': 25, 'reviews_copy4': 25}
#
# Document _id: 9807529 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 40, copies: {'reviews_copy1': 40, 'reviews_copy2': 40, 'reviews_copy3': 40, 'reviews_copy4': 40}
#
# Document _id: 9807679 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 9810515 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 30, copies: {'reviews_copy1': 30, 'reviews_copy2': 30, 'reviews_copy3': 30, 'reviews_copy4': 30}
#
# Document _id: 9815988 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 1, copies: {'reviews_copy1': 1, 'reviews_copy2': 1, 'reviews_copy3': 1, 'reviews_copy4': 1}
#
# Document _id: 9834391 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 19, copies: {'reviews_copy1': 19, 'reviews_copy2': 19, 'reviews_copy3': 19, 'reviews_copy4': 19}
#
# Document _id: 9834713 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 5, copies: {'reviews_copy1': 5, 'reviews_copy2': 5, 'reviews_copy3': 5, 'reviews_copy4': 5}
#
# Document _id: 9846545 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 9848595 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 7, copies: {'reviews_copy1': 7, 'reviews_copy2': 7, 'reviews_copy3': 7, 'reviews_copy4': 7}
#
# Document _id: 9848837 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 1, copies: {'reviews_copy1': 1, 'reviews_copy2': 1, 'reviews_copy3': 1, 'reviews_copy4': 1}
#
# Document _id: 9849915 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 19, copies: {'reviews_copy1': 19, 'reviews_copy2': 19, 'reviews_copy3': 19, 'reviews_copy4': 19}
#
# Document _id: 9853331 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 91, copies: {'reviews_copy1': 91, 'reviews_copy2': 91, 'reviews_copy3': 91, 'reviews_copy4': 91}
#
# Document _id: 9867316 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 180, copies: {'reviews_copy1': 180, 'reviews_copy2': 180, 'reviews_copy3': 180, 'reviews_copy4': 180}
#
# Document _id: 9887054 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 4, copies: {'reviews_copy1': 4, 'reviews_copy2': 4, 'reviews_copy3': 4, 'reviews_copy4': 4}
#
# Document _id: 9895628 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 1, copies: {'reviews_copy1': 1, 'reviews_copy2': 1, 'reviews_copy3': 1, 'reviews_copy4': 1}
#
# Document _id: 9907103 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 55, copies: {'reviews_copy1': 55, 'reviews_copy2': 55, 'reviews_copy3': 55, 'reviews_copy4': 55}
#
# Document _id: 9907907 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 9908871 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 9917859 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 20, copies: {'reviews_copy1': 20, 'reviews_copy2': 20, 'reviews_copy3': 20, 'reviews_copy4': 20}
#
# Document _id: 9936016 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 9937100 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 133, copies: {'reviews_copy1': 133, 'reviews_copy2': 133, 'reviews_copy3': 133, 'reviews_copy4': 133}
#
# Document _id: 9944044 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 1, copies: {'reviews_copy1': 1, 'reviews_copy2': 1, 'reviews_copy3': 1, 'reviews_copy4': 1}
#
# Document _id: 9951865 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 1, copies: {'reviews_copy1': 1, 'reviews_copy2': 1, 'reviews_copy3': 1, 'reviews_copy4': 1}
#
# Document _id: 9969335 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 42, copies: {'reviews_copy1': 42, 'reviews_copy2': 42, 'reviews_copy3': 42, 'reviews_copy4': 42}
#
# Document _id: 9979991 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 9981541 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 3, copies: {'reviews_copy1': 3, 'reviews_copy2': 3, 'reviews_copy3': 3, 'reviews_copy4': 3}
#
# Document _id: 9983221 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 107, copies: {'reviews_copy1': 107, 'reviews_copy2': 107, 'reviews_copy3': 107, 'reviews_copy4': 107}
#
# Document _id: 9985696 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 0, copies: {'reviews_copy1': 0, 'reviews_copy2': 0, 'reviews_copy3': 0, 'reviews_copy4': 0}
#
# Document _id: 9987200 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 90, copies: {'reviews_copy1': 90, 'reviews_copy2': 90, 'reviews_copy3': 90, 'reviews_copy4': 90}
#
# Document _id: 9990304 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 13, copies: {'reviews_copy1': 13, 'reviews_copy2': 13, 'reviews_copy3': 13, 'reviews_copy4': 13}
#
# Document _id: 9993190 - All 'reviews_copy*' arrays match 'reviews'.
# Review counts - reviews: 15, copies: {'reviews_copy1': 15, 'reviews_copy2': 15, 'reviews_copy3': 15, 'reviews_copy4': 15}
#
# Summary:
# {'execution_time_seconds': 2.449345588684082,
#  'mismatches_found': 0,
#  'total_documents': 5555}

# %% [markdown]
# ---

# %% [markdown]
# # **🔍 Queries**

# %% [markdown]
# ## **🛋️Standard Difficulty Questions** [2 points per question]

# %% [markdown]
# ### **Question 2** Select Three Superhosts with At Least Two Listings for >4 People

# %%
# 2)	Once a month, we reward hosts with recognition. 
#       Select three superhosts with at least two listings that can accommodate more than four people.

# 2. Select three superhosts with at least two listings accommodating more than four people
start_time = time.time()

pipeline = [
    # Filter for superhosts and listings accommodating >4
    {"$match": {"host_is_superhost": True, "accommodates": {"$gt": 4}}},
    # Group by host_id to count listings and collect accommodates values
    {"$group": {
        "_id": "$host_id",
        "HostName": {"$first": "$host_name"},
        "ListingCount": {"$sum": 1},
        "AccommodatesList": {"$push": "$accommodates"}  # Collect all accommodates values
    }},
    # Filter for hosts with at least 2 listings
    {"$match": {"ListingCount": {"$gte": 2}}},
    # Sort by host name for consistency
    {"$sort": {"HostName": 1}},
    
    # Limit to 3 superhosts
    # {"$limit": 3},
    
    # Project output without _id
    {"$project": {
        "_id": 0,
        "HostName": 1,
        "ListingCount": 1,
        "AccommodatesList": 1  # Include the list of accommodation capacities
    }}
]

result = list(db.listingsAndReviews_HW2.aggregate(pipeline))
execution_time = time.time() - start_time

# Output
pprint(result)
pprint(f"Execution time: {execution_time:.4f} seconds")
# Out:
# [{'AccommodatesList': [16, 16], 'HostName': 'Aj', 'ListingCount': 2},
#  {'AccommodatesList': [5, 12], 'HostName': 'Aline', 'ListingCount': 2},
#  {'AccommodatesList': [5, 8],
#   'HostName': 'Assunção De Fatima',
#   'ListingCount': 2},
#  {'AccommodatesList': [5, 16], 'HostName': 'Daniel', 'ListingCount': 2},
#  {'AccommodatesList': [14, 6, 6], 'HostName': 'Elite', 'ListingCount': 3},
#  {'AccommodatesList': [5, 6, 6],
#   'HostName': 'Great Vacation Retreats',
#   'ListingCount': 3},
#  {'AccommodatesList': [6, 9], 'HostName': 'Jane', 'ListingCount': 2},
#  {'AccommodatesList': [6, 8], 'HostName': 'Liiiving', 'ListingCount': 2},
#  {'AccommodatesList': [5, 5], 'HostName': 'Miguel & João', 'ListingCount': 2},
#  {'AccommodatesList': [6, 6], 'HostName': 'Mindy', 'ListingCount': 2},
#  {'AccommodatesList': [8, 8, 8],
#   'HostName': 'Patty And Beckett',
#   'ListingCount': 3},
#  {'AccommodatesList': [8, 8], 'HostName': 'Resortica', 'ListingCount': 2},
#  {'AccommodatesList': [9, 8], 'HostName': 'Wilson&Shan', 'ListingCount': 2},
#  {'AccommodatesList': [8, 6], 'HostName': 'Yaiza', 'ListingCount': 2}]
# 'Execution time: 0.0133 seconds'

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# #### **CERTO!**
#
# </div>

# %% [markdown]
# ### **Question 3** Most Common Bed Type in New York with Waterfront and Dishwasher

# %%
# 3)	The company considers inevsting into property to rent. 
#       Which bed type is most common in listings with a waterfront and a dishwasher in New York?

# 3. Most common bed type in New York listings with waterfront and dishwasher
start_time = time.time()

pipeline = [
    # Filter for New York, waterfront, and dishwasher (case-insensitive)
    {"$match": {
        "address.market": "New York",
        "amenities": {
            "$elemMatch": {"$regex": "waterfront", "$options": "i"}  # Matches any waterfront variant
        },
        "amenities": {
            "$elemMatch": {"$regex": "dishwasher", "$options": "i"}  # Matches any dishwasher variant
        }
    }},
    # Group by bed_type and count occurrences
    {"$group": {
        "_id": "$bed_type",
        "Count": {"$sum": 1}
    }},
    # Sort by count descending
    {"$sort": {"Count": -1}},
    # Limit to 1 (most common)
    {"$limit": 1},
    # Project output
    {"$project": {
        "_id": 0,
        "BedType": "$_id",
        "Count": 1
    }}
]

result = list(db.listingsAndReviews_HW2.aggregate(pipeline))
execution_time = time.time() - start_time

# Output
pprint(result)
pprint(f"Execution time: {execution_time:.4f} seconds")
# Out:
# [{'BedType': 'Real Bed', 'Count': 75}]
# 'Execution time: 0.0334 seconds'

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# #### **CERTO!**
#
# </div>

# %% [markdown]
# ### **Question 4** Longest Review in New York

# %%
# 4)	We're considering hiring someone to write reviews professionally. 
#       Who wrote the longest review in New York?

# 4. Reviewer who wrote the longest review in New York
start_time = time.time()

pipeline = [
    # Filter for New York
    {"$match": {"address.market": "New York"}},
    # Unwind reviews array
    {"$unwind": "$reviews"},
    # Project review length and reviewer, handling null comments
    {"$project": {
        "_id": 0,
        "ReviewerName": "$reviews.reviewer_name",
        "ReviewLength": {"$strLenCP":                # Source: https://www.mongodb.com/docs/manual/reference/operator/aggregation/strLenCP/
            {"$ifNull": ["$reviews.comments", ""]}}  # Default to empty string if null
    }},
    # Sort by length descending
    {"$sort": {"ReviewLength": -1}},
    # Limit to 1
    {"$limit": 1}
]

result = list(db.listingsAndReviews_HW2.aggregate(pipeline))
execution_time = time.time() - start_time

# Output
pprint(result)
pprint(f"Execution time: {execution_time:.4f} seconds")
# Out:
# [{'ReviewLength': 4665, 'ReviewerName': 'Angela'}]
# 'Execution time: 0.0606 seconds'

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# #### **CERTO!**
#
# </div>

# %% [markdown]
# ### **Question 5** Biggest and Smallest (Price - Security Deposit) Difference per Visitor

# %%
# 5)	To assess the security of different areas, what is the biggest and smallest (price-security deposit) difference per number of visitors at a property?

# 5. Biggest and smallest (price - security deposit) difference per number of visitors
start_time = time.time()

pipeline = [
    # Calculate difference per visitor, converting strings to numbers
    {"$project": {
        "_id": 0,
        "DifferencePerVisitor": {
            "$divide": [
                {"$abs":                                                        # Absolute value of difference
                    {"$subtract": [
                        {"$toDouble": "$price"},                                # Convert price to double
                        {"$toDouble": {"$ifNull": ["$security_deposit", "0"]}}  # Convert security_deposit, default 0
                    ]}
                }
                , "$accommodates"
            ]
        }
    }},
    # Group to find min and max
    {"$group": {
        "_id": None,
        "MaxDifference": {"$max": "$DifferencePerVisitor"},
        "MinDifference": {"$min": "$DifferencePerVisitor"}
    }},
    # Project output with rounding
    {"$project": {
        "_id": 0,
        "MaxDifference": {"$round": ["$MaxDifference", 2]},
        "MinDifference": {"$round": ["$MinDifference", 2]}
    }}
]

result = list(db.listingsAndReviews_HW2.aggregate(pipeline))
execution_time = time.time() - start_time

# Output
pprint(result)
pprint(f"Execution time: {execution_time:.4f} seconds")
# Out:
# [{'MaxDifference': 48842.0, 'MinDifference': 0.0}]
# 'Execution time: 0.0313 seconds'

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# #### **MEIO ERRADO!**
#
# - Vi numa das respostas que o min é 0 (considerou o máx como 19229.5 em valor absoluto)
#   - Já corrigi, mas temos de confirmar os valores e a lógica
#
# </div>

# %% [markdown]
# ### **Question 6** Average Stay Duration per Property Type per City

# %%
# 6)  Identify areas by whether they are typically used for short breaks, like weekend mini breaks, or whether they are more suitable for long trips. 
#     This information support targeted advertising of different customer types. 
#     It is not expected to change much over time so we won’t look to update it, we just require current view. 
#     What is the average duration of stay (in nights) per type of property per city (you can use the maximum_nights to measure length of stays)? 
#     For each property type return the city with the highest and lowest average value.

# 6. Average stay duration per property type per city, with highest and lowest
start_time = time.time()

pipeline = [
    # Group by property type and city, converting maximum_nights to number
    {"$group": {
        "_id": {"PropertyType": "$property_type", "City": "$address.market"},
        "AvgMaxNights": {"$avg": {"$toInt": {"$ifNull": ["$maximum_nights", "0"]}}}  # Convert to int, default 0
    }},
    # Group by property type to find min/max cities
    {"$group": {
        "_id": "$_id.PropertyType",
        "Cities": {
            "$push": {"City": "$_id.City", "AvgMaxNights": "$AvgMaxNights"}
        }
    }},
    # Project min and max per property type
    {"$project": {
        "_id": 0,
        "PropertyType": "$_id",
        "HighestAvgCity": {
            "$arrayElemAt": [
                "$Cities",
                {"$indexOfArray": ["$Cities.AvgMaxNights", {"$max": "$Cities.AvgMaxNights"}]}
            ]
        },
        "LowestAvgCity": {
            "$arrayElemAt": [
                "$Cities",
                {"$indexOfArray": ["$Cities.AvgMaxNights", {"$min": "$Cities.AvgMaxNights"}]}
            ]
        }
    }}
]

result = list(db.listingsAndReviews_HW2.aggregate(pipeline))
execution_time = time.time() - start_time

# Output
pprint(result)
pprint(f"Execution time: {execution_time:.4f} seconds")
# Out:
# [{'HighestAvgCity': {'AvgMaxNights': 1125.0, 'City': 'Sydney'},
#   'LowestAvgCity': {'AvgMaxNights': 30.0, 'City': 'Istanbul'},
#   'PropertyType': 'Chalet'},
#  {'HighestAvgCity': {'AvgMaxNights': 1125.0, 'City': 'Montreal'},
#   'LowestAvgCity': {'AvgMaxNights': 120.0, 'City': 'Maui'},
#   'PropertyType': 'Cabin'},
#  {'HighestAvgCity': {'AvgMaxNights': 1125.0, 'City': 'Oahu'},
#   'LowestAvgCity': {'AvgMaxNights': 5.0, 'City': 'Rio De Janeiro'},
#   'PropertyType': 'Tiny house'},
#  {'HighestAvgCity': {'AvgMaxNights': 1125.0, 'City': 'Rio De Janeiro'},
#   'LowestAvgCity': {'AvgMaxNights': 1125.0, 'City': 'Rio De Janeiro'},
#   'PropertyType': 'Earth house'},
#  {'HighestAvgCity': {'AvgMaxNights': 1125.0, 'City': 'Montreal'},
#   'LowestAvgCity': {'AvgMaxNights': 30.0, 'City': 'Porto'},
#   'PropertyType': 'Camper/RV'},
#  {'HighestAvgCity': {'AvgMaxNights': 1125.0, 'City': 'Hong Kong'},
#   'LowestAvgCity': {'AvgMaxNights': 1125.0, 'City': 'Hong Kong'},
#   'PropertyType': 'Pension (South Korea)'},
#  {'HighestAvgCity': {'AvgMaxNights': 1125.0, 'City': 'Other (Domestic)'},
#   'LowestAvgCity': {'AvgMaxNights': 30.0, 'City': ''},
#   'PropertyType': 'Condominium'},
#  {'HighestAvgCity': {'AvgMaxNights': 30.0, 'City': 'The Big Island'},
#   'LowestAvgCity': {'AvgMaxNights': 30.0, 'City': 'The Big Island'},
#   'PropertyType': 'Hut'},
#  {'HighestAvgCity': {'AvgMaxNights': 1125.0, 'City': 'Montreal'},
#   'LowestAvgCity': {'AvgMaxNights': 485.0, 'City': 'Oahu'},
#   'PropertyType': 'Bungalow'},
#  {'HighestAvgCity': {'AvgMaxNights': 1125.0, 'City': 'Montreal'},
#   'LowestAvgCity': {'AvgMaxNights': 15.0, 'City': 'Barcelona'},
#   'PropertyType': 'Villa'},
#  {'HighestAvgCity': {'AvgMaxNights': 1125.0, 'City': 'Hong Kong'},
#   'LowestAvgCity': {'AvgMaxNights': 1125.0, 'City': 'Hong Kong'},
#   'PropertyType': 'Houseboat'},
#  {'HighestAvgCity': {'AvgMaxNights': 5200437.653753026, 'City': 'Istanbul'},
#   'LowestAvgCity': {'AvgMaxNights': 371.3636363636364,
#                     'City': 'The Big Island'},
#   'PropertyType': 'Apartment'},
#  {'HighestAvgCity': {'AvgMaxNights': 1125.0, 'City': 'Barcelona'},
#   'LowestAvgCity': {'AvgMaxNights': 235.4, 'City': 'Istanbul'},
#   'PropertyType': 'Casa particular (Cuba)'},
#  {'HighestAvgCity': {'AvgMaxNights': 1125.0, 'City': 'Istanbul'},
#   'LowestAvgCity': {'AvgMaxNights': 469.6, 'City': 'Sydney'},
#   'PropertyType': 'Guesthouse'},
#  {'HighestAvgCity': {'AvgMaxNights': 14.0, 'City': 'Hong Kong'},
#   'LowestAvgCity': {'AvgMaxNights': 14.0, 'City': 'Hong Kong'},
#   'PropertyType': 'Heritage hotel (India)'},
#  {'HighestAvgCity': {'AvgMaxNights': 1125.0, 'City': 'Rio De Janeiro'},
#   'LowestAvgCity': {'AvgMaxNights': 30.0, 'City': ''},
#   'PropertyType': 'Townhouse'},
#  {'HighestAvgCity': {'AvgMaxNights': 1125.0, 'City': 'Oahu'},
#   'LowestAvgCity': {'AvgMaxNights': 30.0, 'City': 'New York'},
#   'PropertyType': 'Other'},
#  {'HighestAvgCity': {'AvgMaxNights': 1125.0, 'City': 'Other (International)'},
#   'LowestAvgCity': {'AvgMaxNights': 572.3617021276596, 'City': 'New York'},
#   'PropertyType': 'House'},
#  {'HighestAvgCity': {'AvgMaxNights': 1125.0, 'City': 'The Big Island'},
#   'LowestAvgCity': {'AvgMaxNights': 1125.0, 'City': 'The Big Island'},
#   'PropertyType': 'Barn'},
#  {'HighestAvgCity': {'AvgMaxNights': 1125.0, 'City': 'Montreal'},
#   'LowestAvgCity': {'AvgMaxNights': 1125.0, 'City': 'Montreal'},
#   'PropertyType': 'Castle'},
#  {'HighestAvgCity': {'AvgMaxNights': 1125.0, 'City': 'Maui'},
#   'LowestAvgCity': {'AvgMaxNights': 28.0, 'City': 'The Big Island'},
#   'PropertyType': 'Loft'},
#  {'HighestAvgCity': {'AvgMaxNights': 1125.0, 'City': 'Maui'},
#   'LowestAvgCity': {'AvgMaxNights': 90.0, 'City': 'Istanbul'},
#   'PropertyType': 'Nature lodge'},
#  {'HighestAvgCity': {'AvgMaxNights': 1125.0, 'City': 'Barcelona'},
#   'LowestAvgCity': {'AvgMaxNights': 14.0, 'City': 'Kauai'},
#   'PropertyType': 'Guest suite'},
#  {'HighestAvgCity': {'AvgMaxNights': 30.0, 'City': 'The Big Island'},
#   'LowestAvgCity': {'AvgMaxNights': 30.0, 'City': 'The Big Island'},
#   'PropertyType': 'Treehouse'},
#  {'HighestAvgCity': {'AvgMaxNights': 1125.0, 'City': 'Kauai'},
#   'LowestAvgCity': {'AvgMaxNights': 577.5, 'City': 'Oahu'},
#   'PropertyType': 'Boutique hotel'},
#  {'HighestAvgCity': {'AvgMaxNights': 1125.0, 'City': 'New York'},
#   'LowestAvgCity': {'AvgMaxNights': 10.0, 'City': 'Sydney'},
#   'PropertyType': 'Hostel'},
#  {'HighestAvgCity': {'AvgMaxNights': 1125.0, 'City': 'Sydney'},
#   'LowestAvgCity': {'AvgMaxNights': 1125.0, 'City': 'Sydney'},
#   'PropertyType': 'Train'},
#  {'HighestAvgCity': {'AvgMaxNights': 1125.0, 'City': 'Porto'},
#   'LowestAvgCity': {'AvgMaxNights': 846.0, 'City': 'The Big Island'},
#   'PropertyType': 'Farm stay'},
#  {'HighestAvgCity': {'AvgMaxNights': 1125.0, 'City': 'Oahu'},
#   'LowestAvgCity': {'AvgMaxNights': 30.0, 'City': 'Kauai'},
#   'PropertyType': 'Bed and breakfast'},
#  {'HighestAvgCity': {'AvgMaxNights': 1125.0, 'City': 'Porto'},
#   'LowestAvgCity': {'AvgMaxNights': 1125.0, 'City': 'Porto'},
#   'PropertyType': 'Boat'},
#  {'HighestAvgCity': {'AvgMaxNights': 1125.0, 'City': 'Oahu'},
#   'LowestAvgCity': {'AvgMaxNights': 180.0, 'City': 'New York'},
#   'PropertyType': 'Serviced apartment'},
#  {'HighestAvgCity': {'AvgMaxNights': 1125.0, 'City': 'New York'},
#   'LowestAvgCity': {'AvgMaxNights': 60.0, 'City': 'Oahu'},
#   'PropertyType': 'Aparthotel'},
#  {'HighestAvgCity': {'AvgMaxNights': 1125.0, 'City': 'Oahu'},
#   'LowestAvgCity': {'AvgMaxNights': 410.0, 'City': 'Maui'},
#   'PropertyType': 'Cottage'},
#  {'HighestAvgCity': {'AvgMaxNights': 1125.0, 'City': 'Oahu'},
#   'LowestAvgCity': {'AvgMaxNights': 7.0, 'City': 'Maui'},
#   'PropertyType': 'Resort'},
#  {'HighestAvgCity': {'AvgMaxNights': 1125.0, 'City': 'Maui'},
#   'LowestAvgCity': {'AvgMaxNights': 35.0, 'City': 'Other (International)'},
#   'PropertyType': 'Hotel'},
#  {'HighestAvgCity': {'AvgMaxNights': 30.0, 'City': 'Oahu'},
#   'LowestAvgCity': {'AvgMaxNights': 30.0, 'City': 'Oahu'},
#   'PropertyType': 'Campsite'}]
# 'Execution time: 0.0216 seconds'

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# #### **MEIO CERTO!**
#
# - Mas vi numa das resoluções que existem "listings presenting about 14 000 years of average maximum nights" e por isso usaram a **`MEDIANA`** em vez da **`MÉDIA`**.
#   - Vamos confirmar e corrigir se necessário
#
# </div>

# %% [markdown]
# ---

# %% [markdown]
# ## **⏳Advanced Difficulty Questions** [3 points per question]
#
# (Consider database optimization for these queries)

# %% [markdown]
# ### **Question 7** Unique Amenities for Host Registration

# %%
# 7)	We are creating a new webpage for hosts when setting up their account. 
#       It will list suggested typical amenities. 
#       This data will need to be available every time a host registers a property but is not expected to change very much. 
#       The starting point for the list will be all unique amenities currently listed in properties (across all documents). 
#       Optimise the database for this use case and show how the data should be queried.

# 7. All unique amenities across listings
start_time = time.time()

pipeline = [
    # Unwind amenities array
    {"$unwind": "$amenities"},
    # Group to get unique amenities
    {"$group": {"_id": "$amenities"}},
    # Project output
    {"$project": {"_id": 0, "Amenity": "$_id"}},
    # Sort alphabetically
    {"$sort": {"Amenity": 1}}
]

result = list(db.listingsAndReviews_HW2.aggregate(pipeline))
execution_time = time.time() - start_time

# Output
pprint(result)
print(f"\n\33[1mTotal unique amenities: {len(result)}\33[0m")
pprint(f"Execution time: {execution_time:.4f} seconds")
# Out:
# [{'Amenity': ''},
#  {'Amenity': '24-hour check-in'},
#  {'Amenity': 'Accessible-height bed'},
#  {'Amenity': 'Accessible-height toilet'},
#  {'Amenity': 'Air conditioning'},
#  {'Amenity': 'Air purifier'},
#  {'Amenity': 'Alfresco shower'},
#  {'Amenity': 'BBQ grill'},
#  {'Amenity': 'Baby bath'},
#  {'Amenity': 'Baby monitor'},
#  {'Amenity': 'Babysitter recommendations'},
#  {'Amenity': 'Balcony'},
#  {'Amenity': 'Bath towel'},
#  {'Amenity': 'Bathroom essentials'},
#  {'Amenity': 'Bathtub'},
#  {'Amenity': 'Bathtub with bath chair'},
#  {'Amenity': 'Beach chairs'},
#  {'Amenity': 'Beach essentials'},
#  {'Amenity': 'Beach view'},
#  {'Amenity': 'Beachfront'},
#  {'Amenity': 'Bed linens'},
#  {'Amenity': 'Bedroom comforts'},
#  {'Amenity': 'Bicycle'},
#  {'Amenity': 'Bidet'},
#  {'Amenity': 'Body soap'},
#  {'Amenity': 'Boogie boards'},
#  {'Amenity': 'Breakfast'},
#  {'Amenity': 'Breakfast bar'},
#  {'Amenity': 'Breakfast table'},
#  {'Amenity': 'Building staff'},
#  {'Amenity': 'Buzzer/wireless intercom'},
#  {'Amenity': 'Cable TV'},
#  {'Amenity': 'Carbon monoxide detector'},
#  {'Amenity': 'Cat(s)'},
#  {'Amenity': 'Ceiling fan'},
#  {'Amenity': 'Central air conditioning'},
#  {'Amenity': 'Changing table'},
#  {'Amenity': "Chef's kitchen"},
#  {'Amenity': 'Children’s books and toys'},
#  {'Amenity': 'Children’s dinnerware'},
#  {'Amenity': 'Cleaning before checkout'},
#  {'Amenity': 'Coffee maker'},
#  {'Amenity': 'Convection oven'},
#  {'Amenity': 'Cooking basics'},
#  {'Amenity': 'Crib'},
#  {'Amenity': 'DVD player'},
#  {'Amenity': 'Day bed'},
#  {'Amenity': 'Dining area'},
#  {'Amenity': 'Disabled parking spot'},
#  {'Amenity': 'Dishes and silverware'},
#  {'Amenity': 'Dishwasher'},
#  {'Amenity': 'Dog(s)'},
#  {'Amenity': 'Doorman'},
#  {'Amenity': 'Double oven'},
#  {'Amenity': 'Dryer'},
#  {'Amenity': 'EV charger'},
#  {'Amenity': 'Electric profiling bed'},
#  {'Amenity': 'Elevator'},
#  {'Amenity': 'En suite bathroom'},
#  {'Amenity': 'Espresso machine'},
#  {'Amenity': 'Essentials'},
#  {'Amenity': 'Ethernet connection'},
#  {'Amenity': 'Extra pillows and blankets'},
#  {'Amenity': 'Family/kid friendly'},
#  {'Amenity': 'Fax machine'},
#  {'Amenity': 'Fire extinguisher'},
#  {'Amenity': 'Fireplace guards'},
#  {'Amenity': 'Firm mattress'},
#  {'Amenity': 'First aid kit'},
#  {'Amenity': 'Fixed grab bars for shower'},
#  {'Amenity': 'Fixed grab bars for toilet'},
#  {'Amenity': 'Flat path to front door'},
#  {'Amenity': 'Formal dining area'},
#  {'Amenity': 'Free parking on premises'},
#  {'Amenity': 'Free street parking'},
#  {'Amenity': 'Full kitchen'},
#  {'Amenity': 'Game console'},
#  {'Amenity': 'Garden or backyard'},
#  {'Amenity': 'Gas oven'},
#  {'Amenity': 'Ground floor access'},
#  {'Amenity': 'Gym'},
#  {'Amenity': 'Hair dryer'},
#  {'Amenity': 'Handheld shower head'},
#  {'Amenity': 'Hangers'},
#  {'Amenity': 'Heated towel rack'},
#  {'Amenity': 'Heating'},
#  {'Amenity': 'High chair'},
#  {'Amenity': 'Home theater'},
#  {'Amenity': 'Host greets you'},
#  {'Amenity': 'Hot tub'},
#  {'Amenity': 'Hot water'},
#  {'Amenity': 'Hot water kettle'},
#  {'Amenity': 'Ice Machine'},
#  {'Amenity': 'Indoor fireplace'},
#  {'Amenity': 'Internet'},
#  {'Amenity': 'Iron'},
#  {'Amenity': 'Ironing Board'},
#  {'Amenity': 'Kayak'},
#  {'Amenity': 'Keypad'},
#  {'Amenity': 'Kitchen'},
#  {'Amenity': 'Kitchenette'},
#  {'Amenity': 'Lake access'},
#  {'Amenity': 'Laptop friendly workspace'},
#  {'Amenity': 'Lock on bedroom door'},
#  {'Amenity': 'Lockbox'},
#  {'Amenity': 'Long term stays allowed'},
#  {'Amenity': 'Luggage dropoff allowed'},
#  {'Amenity': 'Memory foam mattress'},
#  {'Amenity': 'Microwave'},
#  {'Amenity': 'Mini fridge'},
#  {'Amenity': 'Mountain view'},
#  {'Amenity': 'Murphy bed'},
#  {'Amenity': 'Netflix'},
#  {'Amenity': 'Other'},
#  {'Amenity': 'Other pet(s)'},
#  {'Amenity': 'Outdoor parking'},
#  {'Amenity': 'Outdoor seating'},
#  {'Amenity': 'Outlet covers'},
#  {'Amenity': 'Oven'},
#  {'Amenity': 'Pack ’n Play/travel crib'},
#  {'Amenity': 'Paid parking off premises'},
#  {'Amenity': 'Paid parking on premises'},
#  {'Amenity': 'Parking'},
#  {'Amenity': 'Patio or balcony'},
#  {'Amenity': 'Permit parking'},
#  {'Amenity': 'Pets allowed'},
#  {'Amenity': 'Pets live on this property'},
#  {'Amenity': 'Pillow-top mattress'},
#  {'Amenity': 'Pocket wifi'},
#  {'Amenity': 'Pool'},
#  {'Amenity': 'Pool with pool hoist'},
#  {'Amenity': 'Private bathroom'},
#  {'Amenity': 'Private entrance'},
#  {'Amenity': 'Private hot tub'},
#  {'Amenity': 'Private living room'},
#  {'Amenity': 'Private pool'},
#  {'Amenity': 'Rain shower'},
#  {'Amenity': 'Refrigerator'},
#  {'Amenity': 'Roll-in shower'},
#  {'Amenity': 'Room-darkening shades'},
#  {'Amenity': 'Safe'},
#  {'Amenity': 'Safety card'},
#  {'Amenity': 'Sauna'},
#  {'Amenity': 'Self check-in'},
#  {'Amenity': 'Shampoo'},
#  {'Amenity': 'Shared pool'},
#  {'Amenity': 'Shower chair'},
#  {'Amenity': 'Single level home'},
#  {'Amenity': 'Ski-in/Ski-out'},
#  {'Amenity': 'Smart TV'},
#  {'Amenity': 'Smart lock'},
#  {'Amenity': 'Smoke detector'},
#  {'Amenity': 'Smoking allowed'},
#  {'Amenity': 'Snorkeling equipment'},
#  {'Amenity': 'Sonos sound system'},
#  {'Amenity': 'Sound system'},
#  {'Amenity': 'Stair gates'},
#  {'Amenity': 'Standing valet'},
#  {'Amenity': 'Step-free access'},
#  {'Amenity': 'Stove'},
#  {'Amenity': 'Suitable for events'},
#  {'Amenity': 'Sun loungers'},
#  {'Amenity': 'Swimming pool'},
#  {'Amenity': 'TV'},
#  {'Amenity': 'Table corner guards'},
#  {'Amenity': 'Tennis court'},
#  {'Amenity': 'Terrace'},
#  {'Amenity': 'Toaster'},
#  {'Amenity': 'Toilet paper'},
#  {'Amenity': 'Walk-in shower'},
#  {'Amenity': 'Warming drawer'},
#  {'Amenity': 'Washer'},
#  {'Amenity': 'Washer / Dryer'},
#  {'Amenity': 'Waterfront'},
#  {'Amenity': 'Well-lit path to entrance'},
#  {'Amenity': 'Wheelchair accessible'},
#  {'Amenity': 'Wide clearance to bed'},
#  {'Amenity': 'Wide clearance to shower'},
#  {'Amenity': 'Wide doorway'},
#  {'Amenity': 'Wide entryway'},
#  {'Amenity': 'Wide hallway clearance'},
#  {'Amenity': 'Wifi'},
#  {'Amenity': 'Window guards'},
#  {'Amenity': 'toilet'},
#  {'Amenity': 'translation missing: en.hosting_amenity_49'},
#  {'Amenity': 'translation missing: en.hosting_amenity_50'}]
#
# Total unique amenities: 186
# 'Execution time: 0.0928 seconds'

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# #### **MEIO CERTO!**
#
# - Vi numa das resoluções que no total deu-lhes **106** amenities **& FALTA CRIAR A TAL NOVA COLEÇÃO PARA OTIMIZAR A BASE DE DADOS**
#
# </div>

# %% [markdown]
# ### **Question 8** Top 20 Reviewers and Reviewer Count by ID/Name

# %%
# 8)	We plan to rtack our reviewers better. 
#       We want to create a webpage that shows the top 20 reviewers and the count of the number of reviews of each of these reviewers. 
#       This webpage should be kept up to date. It should also have a link to return the number of reviews for a given reviewer ID or Name 
#           (show how to query for number of reviews by ID or query quickly).

# 8. Top 20 reviewers and count by ID or Name
start_time = time.time()

pipeline = [
    # Unwind reviews
    {"$unwind": "$reviews"},
    # Group by reviewer
    {"$group": {"_id": "$reviews.reviewer_id", "ReviewerName": {"$first": "$reviews.reviewer_name"}, "ReviewCount": {"$sum": 1}}},
    # Sort by count descending
    {"$sort": {"ReviewCount": -1}},
    # Limit to 20
    {"$limit": 20},
    # Project output
    {"$project": {"_id": 0, "ReviewerId": "$_id", "ReviewerName": 1, "ReviewCount": 1}}
]

result = list(db.listingsAndReviews_HW2.aggregate(pipeline))
execution_time = time.time() - start_time

# Output
pprint(result)
pprint(f"Execution time: {execution_time:.4f} seconds")

# Function to get review count by ID or Name
def get_review_count(reviewer_id=None, reviewer_name=None):
    start_time = time.time()
    match = {}
    if reviewer_id:
        match["reviews.reviewer_id"] = reviewer_id
    elif reviewer_name:
        match["reviews.reviewer_name"] = reviewer_name
    pipeline = [
        {"$unwind": "$reviews"},
        {"$match": match},
        {"$group": {"_id": None, "Count": {"$sum": 1}}},
        {"$project": {"_id": 0, "Count": 1}}
    ]
    result = list(db.listingsAndReviews_HW2.aggregate(pipeline))
    exec_time = time.time() - start_time
    return result[0]["Count"] if result else 0, exec_time

count, exec_time = get_review_count(reviewer_id="51483096")
pprint(f"Reviews for ID 51483096: {count}, Time: {exec_time:.4f} seconds")
# Out:
# [{'ReviewCount': 24, 'ReviewerId': '20775242', 'ReviewerName': 'Filipe'},
#  {'ReviewCount': 13, 'ReviewerId': '67084875', 'ReviewerName': 'Nick'},
#  {'ReviewCount': 10, 'ReviewerId': '2961855', 'ReviewerName': 'Uge'},
#  {'ReviewCount': 9, 'ReviewerId': '20991911', 'ReviewerName': 'Lisa'},
#  {'ReviewCount': 9, 'ReviewerId': '162027327', 'ReviewerName': 'Thien'},
#  {'ReviewCount': 8, 'ReviewerId': '60816198', 'ReviewerName': 'Todd'},
#  {'ReviewCount': 8, 'ReviewerId': '69140895', 'ReviewerName': 'Lisa'},
#  {'ReviewCount': 8, 'ReviewerId': '1705870', 'ReviewerName': 'David'},
#  {'ReviewCount': 8, 'ReviewerId': '12679057', 'ReviewerName': 'Jodi'},
#  {'ReviewCount': 8, 'ReviewerId': '55241576', 'ReviewerName': 'Courtney'},
#  {'ReviewCount': 7, 'ReviewerId': '47303133', 'ReviewerName': 'Lance'},
#  {'ReviewCount': 7, 'ReviewerId': '78093968', 'ReviewerName': 'David'},
#  {'ReviewCount': 6, 'ReviewerId': '93859831', 'ReviewerName': 'Pierre'},
#  {'ReviewCount': 6, 'ReviewerId': '57325457', 'ReviewerName': 'Mary'},
#  {'ReviewCount': 6, 'ReviewerId': '34005800', 'ReviewerName': 'Dan'},
#  {'ReviewCount': 6, 'ReviewerId': '76782210', 'ReviewerName': 'Assis'},
#  {'ReviewCount': 6, 'ReviewerId': '24667379', 'ReviewerName': 'Karen'},
#  {'ReviewCount': 6, 'ReviewerId': '73708321', 'ReviewerName': 'Gonzalo'},
#  {'ReviewCount': 6, 'ReviewerId': '128210181', 'ReviewerName': 'Branden'},
#  {'ReviewCount': 6, 'ReviewerId': '61469899', 'ReviewerName': 'Erik'}]
# 'Execution time: 0.3526 seconds'
# 'Reviews for ID 51483096: 1, Time: 0.0974 seconds'

# %% [markdown]
# ### **Question 9** Average Review Scores with Flexible Metrics

# %%
# 9)	For each property we store review scores across different metrics (accuracy, check-in, cleanliness etc). 
#       We consider adding more metrics, although there is no clarity on what these will be. 
#       We want to be able to easily query the average score across all of these metrics, including any new metrics that might be added without changing the query. 
#       Adjust the data model so this can be done and show the query for an example property.

# 9. Average score across all review metrics for a property
start_time = time.time()

pipeline = [
    # Match the specific property
    {"$match": {"_id": "10006546"}},
    # Convert all document fields to an array of key-value pairs
    {"$project": {
        "all_fields": {"$objectToArray": "$$ROOT"}
    }},
    # Unwind the array to process each field
    {"$unwind": "$all_fields"},
    # Filter for fields starting with 'review_scores_'
    {"$match": {
        "all_fields.k": {"$regex": "^review_scores_"}
    }},
    # Project the score values, handling nulls
    {"$project": {
        "_id": 0,
        "Metric": "$all_fields.k",
        "Score": {"$ifNull": ["$all_fields.v", 0]}  # Default to 0 if null
    }},
    
    # [{'Metric': 'review_scores_checkin', 'Score': 10},
    # {'Metric': 'review_scores_cleanliness', 'Score': 9},
    # {'Metric': 'review_scores_communication', 'Score': 10},
    # {'Metric': 'review_scores_location', 'Score': 10},
    # {'Metric': 'review_scores_rating', 'Score': 89},
    # {'Metric': 'review_scores_value', 'Score': 9}]
        
    # Group to calculate the average across all metrics
    {"$group": {
        "_id": None,
        "AvgScore": {"$avg": "$Score"}
    }},
    # Project the final output with rounding
    {"$project": {
        "_id": 0,
        "AvgScore": {"$round": ["$AvgScore", 1]},
    }}
]

result = list(db.listingsAndReviews_HW2.aggregate(pipeline))
execution_time = time.time() - start_time

# Output
pprint(result)
pprint(f"Execution time: {execution_time:.4f} seconds")
# Out:
# [{'Metric': 'review_scores_checkin', 'Score': 10},
#  {'Metric': 'review_scores_cleanliness', 'Score': 9},
#  {'Metric': 'review_scores_communication', 'Score': 10},
#  {'Metric': 'review_scores_location', 'Score': 10},
#  {'Metric': 'review_scores_rating', 'Score': 89},
#  {'Metric': 'review_scores_value', 'Score': 9}]
# 'Execution time: 0.0252 seconds'

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# #### **ERRADO!**
#
# - Acho que a ideia é criar um **SUBDOCUMENTO** com os **`REVIEW SCORES`** e depois fazer a média de todos os valores (e até dira que nem podemos criar logo a média pq ela diz ***including any new metrics that might be added without changing the query***)
#
# </div>

# %% [markdown]
# ### **Question 10** Average Transaction Value in a Period

# %%
# Verify Document Structure - Example Property
doc = db.listingsAndReviews_HW2.find_one({"_id": "10006546"}, {"transactions": 1})
pprint(doc)
# Out:
# {'_id': '10006546',
#  'transactions': {'bucket_end_date': datetime.datetime(2016, 11, 23, 0, 0),
#                   'bucket_start_date': datetime.datetime(1979, 10, 4, 0, 0),
#                   'transaction_count': 21,
#                   'transactions': [{'date': datetime.datetime(2008, 8, 12, 0, 0),
#                                     'price': '132.106378168429131392258568666875362396240234375'},
#                                    {'date': datetime.datetime(1999, 3, 9, 0, 0),
#                                     'price': '23.70647577039597564407813479192554950714111328125'},
#                                    {'date': datetime.datetime(2016, 6, 15, 0, 0),
#                                     'price': '6.88059855597928216042191706947050988674163818359375'},
#                                    {'date': datetime.datetime(2015, 12, 17, 0, 0),
#                                     'price': '2.585702399312638899431249228655360639095306396484375'},
#                                    {'date': datetime.datetime(2015, 2, 3, 0, 0),
#                                     'price': '2.56992480431307068755586442421190440654754638671875'},
#                                    {'date': datetime.datetime(1997, 9, 8, 0, 0),
#                                     'price': '7.25175972756794973150817895657382905483245849609375'},
#                                    {'date': datetime.datetime(2004, 9, 8, 0, 0),
#                                     'price': '15.9010861019132772042894430342130362987518310546875'},
#                                    {'date': datetime.datetime(2012, 10, 25, 0, 0),
#                                     'price': '7.596732654304002352319002966396510601043701171875'},
#                                    {'date': datetime.datetime(2013, 3, 22, 0, 0),
#                                     'price': '43.81164129126756279219989664852619171142578125'},
#                                    {'date': datetime.datetime(2013, 7, 12, 0, 0),
#                                     'price': '3.53027623850000704663898432045243680477142333984375'},
#                                    {'date': datetime.datetime(2014, 5, 6, 0, 0),
#                                     'price': '3.73682168490311905628686872660182416439056396484375'},
#                                    {'date': datetime.datetime(2009, 2, 13, 0, 0),
#                                     'price': '13.39452362785547023804610944353044033050537109375'},
#                                    {'date': datetime.datetime(1985, 7, 10, 0, 0),
#                                     'price': '0.440871608469596665269563118272344581782817840576171875'},
#                                    {'date': datetime.datetime(2007, 4, 18, 0, 0),
#                                     'price': '10.719959884928965010431056725792586803436279296875'},
#                                    {'date': datetime.datetime(2009, 10, 29, 0, 0),
#                                     'price': '15.016646415046945861604399397037923336029052734375'},
#                                    {'date': datetime.datetime(2015, 4, 30, 0, 0),
#                                     'price': '2.486600325872291961104565416462719440460205078125'},
#                                    {'date': datetime.datetime(1988, 8, 26, 0, 0),
#                                     'price': '0.71239767066470516265752621620777063071727752685546875'},
#                                    {'date': datetime.datetime(2012, 7, 6, 0, 0),
#                                     'price': '14.257901260816570498946020961739122867584228515625'},
#                                    {'date': datetime.datetime(2012, 11, 16, 0, 0),
#                                     'price': '15.36849155644466691228444688022136688232421875'},
#                                    {'date': datetime.datetime(2011, 4, 6, 0, 0),
#                                     'price': '55.8413713584413784474236308597028255462646484375'},
#                                    {'date': datetime.datetime(2012, 1, 18, 0, 0),
#                                     'price': '8.5396098223326220022499910555779933929443359375'}]}}

# %%
# Check Date Values in Transactions
doc = db.listingsAndReviews_HW2.find_one(
    {"_id": "10006546", "transactions.transactions": {"$exists": True}},
    {"transactions.transactions.date": 1}
)
pprint(doc)
# Out:
# {'_id': '10006546',
#  'transactions': {'transactions': [{'date': datetime.datetime(2008, 8, 12, 0, 0)},
#                                    {'date': datetime.datetime(1999, 3, 9, 0, 0)},
#                                    {'date': datetime.datetime(2016, 6, 15, 0, 0)},
#                                    {'date': datetime.datetime(2015, 12, 17, 0, 0)},
#                                    {'date': datetime.datetime(2015, 2, 3, 0, 0)},
#                                    {'date': datetime.datetime(1997, 9, 8, 0, 0)},
#                                    {'date': datetime.datetime(2004, 9, 8, 0, 0)},
#                                    {'date': datetime.datetime(2012, 10, 25, 0, 0)},
#                                    {'date': datetime.datetime(2013, 3, 22, 0, 0)},
#                                    {'date': datetime.datetime(2013, 7, 12, 0, 0)},
#                                    {'date': datetime.datetime(2014, 5, 6, 0, 0)},
#                                    {'date': datetime.datetime(2009, 2, 13, 0, 0)},
#                                    {'date': datetime.datetime(1985, 7, 10, 0, 0)},
#                                    {'date': datetime.datetime(2007, 4, 18, 0, 0)},
#                                    {'date': datetime.datetime(2009, 10, 29, 0, 0)},
#                                    {'date': datetime.datetime(2015, 4, 30, 0, 0)},
#                                    {'date': datetime.datetime(1988, 8, 26, 0, 0)},
#                                    {'date': datetime.datetime(2012, 7, 6, 0, 0)},
#                                    {'date': datetime.datetime(2012, 11, 16, 0, 0)},
#                                    {'date': datetime.datetime(2011, 4, 6, 0, 0)},
#                                    {'date': datetime.datetime(2012, 1, 18, 0, 0)}]}}

# %%
# # Test Matches - Remove the date filter temporarily to see if any transactions exist
# pipeline = [
#     {"$match": {"_id": "10006546"}},
#     {"$unwind": "$transactions.transactions"},
#     {"$limit": 5}
# ]
# pprint(list(db.listingsAndReviews_HW2.aggregate(pipeline))) - Existes transactions

# %%
# 10)	We aim to have better access to information about transaction, 
#       we wish to develop a search engine that can calculate the average value of transactions in a given period of time quickly for a given property.
from datetime import datetime

# 10. Average transaction value for a property in a date range
start_time = time.time()

pipeline = [
    {"$match": {"_id": "10006546"}},                                            # Match the specific property ID
    {"$unwind": "$transactions.transactions"},                                  # Unwind transactions
    
    # Convert date strings to ISODate and filter
    {"$match": {
        "transactions.transactions.date": {
            "$gte": datetime.strptime("2008-01-01", "%Y-%m-%d"),
            "$lte": datetime.strptime("2009-01-01", "%Y-%m-%d")
        }
    }},
    {"$group": {
        "_id": None,
        "AvgValue": {"$avg": {"$toDouble": "$transactions.transactions.price"}}  # Convert price to number
    }},
    {"$project": {"_id": 0, "AvgValue": {"$round": ["$AvgValue", 2]}}}
]

result = list(db.listingsAndReviews_HW2.aggregate(pipeline))
execution_time = time.time() - start_time

# Output
pprint(result)
pprint(f"Execution time: {execution_time:.4f} seconds")
# Out:
# [{'AvgValue': 132.11}]
# 'Execution time: 0.0030 seconds'

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# #### **MEIO CERTO!**
#
# - Querem criar tipo um mini "programa" só com prints, inputs e outputs (com as devidas verificações)??
#
# </div>

# %% [markdown]
# ### **Question 11**  Top 10 Cities Summary

# %%
# 11)	We wish to have a summary webpage that displays information about our top destinations. 
#       This webpage should display for each of the top 10 cities some basic information about our operations in the area 
#           (number of properties by type for example, average price by type) but you can choose the metrics. 
#       For each of the top 10 cities it should also provide some basic information about the top 3 properties in each city 
#           (price, number of review, whatever you think useful) to show an example of the properties available in the area. 
#       We would like to keep this webpage up to date as information changes.

# 11. Top 10 cities with property stats and top 3 properties
start_time = time.time()

pipeline = [
    # Group by city
    {"$group": {
        "_id": "$address.market",
        "PropertyCount": {"$sum": 1},
        "AvgPrice": {"$avg": "$price"},
        "Properties": {"$push": {"Id": "$_id", "Price": "$price", "ReviewCount": "$number_of_reviews"}}
    }},
    # Sort by property count
    {"$sort": {"PropertyCount": -1}},
    # Limit to top 10 cities
    {"$limit": 10},
    # Add top 3 properties per city
    {"$project": {
        "_id": 0,
        "City": "$_id",
        "PropertyCount": 1,
        "AvgPrice": {"$round": ["$AvgPrice", 2]},
        "TopProperties": {"$slice": [{"$sortArray": {"input": "$Properties", "sortBy": {"ReviewCount": -1}}}, 3]}
    }}
]

result = list(db.listingsAndReviews_HW2.aggregate(pipeline))
execution_time = time.time() - start_time

# Output
pprint(result)
pprint(f"Execution time: {execution_time:.4f} seconds")

# Print the only the top 10 cities
top_cities = [city["City"] for city in result]
propertycount = [city["PropertyCount"] for city in result]
print(f"\n\033[1mTop 10 cities:\033[0m {top_cities} - {propertycount} properties")
# Out:
# [{'AvgPrice': Decimal128('367.95'),
#   'City': 'Istanbul',
#   'PropertyCount': 660,
#   'TopProperties': [{'Id': '3237666',
#                      'Price': Decimal128('148.00'),
#                      'ReviewCount': 248},
#                     {'Id': '555588',
#                      'Price': Decimal128('243.00'),
#                      'ReviewCount': 246},
#                     {'Id': '1215226',
#                      'Price': Decimal128('322.00'),
#                      'ReviewCount': 193}]},
#  {'AvgPrice': Decimal128('100.23'),
#   'City': 'Montreal',
#   'PropertyCount': 648,
#   'TopProperties': [{'Id': '16389574',
#                      'Price': Decimal128('70.00'),
#                      'ReviewCount': 261},
#                     {'Id': '4451485',
#                      'Price': Decimal128('83.00'),
#                      'ReviewCount': 255},
#                     {'Id': '16845784',
#                      'Price': Decimal128('50.00'),
#                      'ReviewCount': 176}]},
#  {'AvgPrice': Decimal128('100.95'),
#   'City': 'Barcelona',
#   'PropertyCount': 632,
#   'TopProperties': [{'Id': '95560',
#                      'Price': Decimal128('15.00'),
#                      'ReviewCount': 463},
#                     {'Id': '1482060',
#                      'Price': Decimal128('130.00'),
#                      'ReviewCount': 397},
#                     {'Id': '1332929',
#                      'Price': Decimal128('63.00'),
#                      'ReviewCount': 320}]},
#  {'AvgPrice': Decimal128('762.48'),
#   'City': 'Hong Kong',
#   'PropertyCount': 619,
#   'TopProperties': [{'Id': '16493868',
#                      'Price': Decimal128('361.00'),
#                      'ReviewCount': 348},
#                     {'Id': '11778475',
#                      'Price': Decimal128('502.00'),
#                      'ReviewCount': 269},
#                     {'Id': '4755673',
#                      'Price': Decimal128('1319.00'),
#                      'ReviewCount': 223}]},
#  {'AvgPrice': Decimal128('197.71'),
#   'City': 'Sydney',
#   'PropertyCount': 609,
#   'TopProperties': [{'Id': '12954762',
#                      'Price': Decimal128('60.00'),
#                      'ReviewCount': 469},
#                     {'Id': '652063',
#                      'Price': Decimal128('43.00'),
#                      'ReviewCount': 312},
#                     {'Id': '7132426',
#                      'Price': Decimal128('139.00'),
#                      'ReviewCount': 259}]},
#  {'AvgPrice': Decimal128('139.56'),
#   'City': 'New York',
#   'PropertyCount': 608,
#   'TopProperties': [{'Id': '476983',
#                      'Price': Decimal128('85.00'),
#                      'ReviewCount': 420},
#                     {'Id': '18173787',
#                      'Price': Decimal128('48.00'),
#                      'ReviewCount': 379},
#                     {'Id': '858695',
#                      'Price': Decimal128('30.00'),
#                      'ReviewCount': 262}]},
#  {'AvgPrice': Decimal128('525.81'),
#   'City': 'Rio De Janeiro',
#   'PropertyCount': 603,
#   'TopProperties': [{'Id': '846689',
#                      'Price': Decimal128('157.00'),
#                      'ReviewCount': 227},
#                     {'Id': '1304552',
#                      'Price': Decimal128('168.00'),
#                      'ReviewCount': 227},
#                     {'Id': '880678',
#                      'Price': Decimal128('190.00'),
#                      'ReviewCount': 149}]},
#  {'AvgPrice': Decimal128('69.13'),
#   'City': 'Porto',
#   'PropertyCount': 554,
#   'TopProperties': [{'Id': '5283892',
#                      'Price': Decimal128('29.00'),
#                      'ReviewCount': 408},
#                     {'Id': '2758817',
#                      'Price': Decimal128('30.00'),
#                      'ReviewCount': 402},
#                     {'Id': '1284759',
#                      'Price': Decimal128('53.00'),
#                      'ReviewCount': 399}]},
#  {'AvgPrice': Decimal128('212.30'),
#   'City': 'Oahu',
#   'PropertyCount': 253,
#   'TopProperties': [{'Id': '4069429',
#                      'Price': Decimal128('124.00'),
#                      'ReviewCount': 533},
#                     {'Id': '7536867',
#                      'Price': Decimal128('60.00'),
#                      'ReviewCount': 308},
#                     {'Id': '210968',
#                      'Price': Decimal128('169.00'),
#                      'ReviewCount': 289}]},
#  {'AvgPrice': Decimal128('286.59'),
#   'City': 'Maui',
#   'PropertyCount': 153,
#   'TopProperties': [{'Id': '1796816',
#                      'Price': Decimal128('175.00'),
#                      'ReviewCount': 257},
#                     {'Id': '1613843',
#                      'Price': Decimal128('95.00'),
#                      'ReviewCount': 192},
#                     {'Id': '2279098',
#                      'Price': Decimal128('86.00'),
#                      'ReviewCount': 176}]}]
# 'Execution time: 0.1693 seconds'
#
# Top 10 cities: ['Istanbul', 'Montreal', 'Barcelona', 'Hong Kong', 'Sydney', 'New York', 'Rio De Janeiro', 'Porto', 'Oahu', 'Maui'] - [660, 648, 632, 619, 609, 608, 603, 554, 253, 153] properties

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# #### **MEIO CERTO!**
#
# - Faz printar com as cenas que eles querem
#   - Numa das resoluções vi a cidade "The Big Island" e não sei se é uma cidade ou se é um erro
#   - Noutra já deu igual a nós! :)
#
# </div>

# %% [markdown]
# ---

# %% [markdown]
# ## **🔄️ Database updates:** [2 points per question]
#
# After optimizing the database, show how to complete the following updates. You can create fictional data. Ensure that previous data does not become stale:

# %% [markdown]
# ### **Question 12**  Add New Property

# %%
# 12) Add a new property with a new host in one of the top 10 cities. 
#     The host selects the top 10 most common amenities to list.

# 12. Add new property with top 10 amenities
start_time = time.time()

# Top 10 amenities from Query 7 (manually selected based on frequency)
top_amenities = [
    "TV", "Wifi", "Kitchen", "Heating", "Essentials",
    "Washer", "Dryer", "Air conditioning", "Hair dryer", "Iron"
]
new_property = {
    "_id": "20000000",
    "name": "New York Loft",
    "host_id": "99999999",
    "host_name": "Jane",
    "address": {"market": "New York"},
    "amenities": top_amenities,
    "price": 100.00  # Numeric value
}
db.listingsAndReviews_HW2.insert_one(new_property)
execution_time = time.time() - start_time

# Output
pprint(f"Inserted property: 20000000, Time: {execution_time:.4f} seconds")
# Out:
# 'Inserted property: 20000000, Time: 0.0036 seconds'

# %%
# 12.1) Query the new property to verify the insertion
result = db.listingsAndReviews_HW2.find_one({"_id": "20000000"})
pprint(result)
# Out:
# {'_id': '20000000',
#  'address': {'market': 'New York'},
#  'amenities': ['TV',
#                'Wifi',
#                'Kitchen',
#                'Heating',
#                'Essentials',
#                'Washer',
#                'Dryer',
#                'Air conditioning',
#                'Hair dryer',
#                'Iron'],
#  'host_id': '99999999',
#  'host_name': 'Jane',
#  'name': 'New York Loft',
#  'price': 100.0}

# %% [markdown]
# ### **Question 13** Add New Review

# %%
# 13) Add a new review from one of our top 20 reviewers for this new property.

# %%
# 13.1) Get the top reviewer ID from Question 8

# {'ReviewCount': 24, 'ReviewerId': '20775242', 'ReviewerName': 'Filipe'}
top_reviewer_id = "20775242"
doc = db.listingsAndReviews_HW2.find_one(
    {"reviews.reviewer_id": top_reviewer_id},
    {"host_name": 1, "reviews.$": 1}
)
pprint(doc)

# doc["reviews"][0]['comments'] - Reviewer comments
# Out:
# {'_id': '13574006',
#  'host_name': 'José',
#  'reviews': [{'_id': '256178235',
#               'comments': 'Great stay. The perfect house with the perfect '
#                           'service. We did a last minute booking and '
#                           'everything went smooth. Everything was very clean '
#                           'and the comunication was perfect. The house is '
#                           'incredibly luxorious and fully equppied. Highly '
#                           'recommended',
#               'date': datetime.datetime(2018, 4, 22, 4, 0),
#               'listing_id': '13574006',
#               'reviewer_id': '20775242',
#               'reviewer_name': 'Filipe'}]}

# %%
# 13. Add review from top reviewer
start_time = time.time()

db.listingsAndReviews_HW2.update_one({"_id": "20000000"}, {"$push": {"reviews": doc["reviews"][0]}})
execution_time = time.time() - start_time

# Output
pprint(f"Added review, Time: {execution_time:.4f} seconds")
# Out:
# 'Added review, Time: 0.0026 seconds'

# %%
# 13.1) Query the new review to verify the insertion
result = db.listingsAndReviews_HW2.find_one({"_id": "20000000"})
pprint(result)
# Out:
# {'_id': '20000000',
#  'address': {'market': 'New York'},
#  'amenities': ['TV',
#                'Wifi',
#                'Kitchen',
#                'Heating',
#                'Essentials',
#                'Washer',
#                'Dryer',
#                'Air conditioning',
#                'Hair dryer',
#                'Iron'],
#  'host_id': '99999999',
#  'host_name': 'Jane',
#  'name': 'New York Loft',
#  'price': 100.0,
#  'review_scores_x_factor': 10,
#  'reviews': [{'_id': '99999999',
#               'comments': 'Nice loft!',
#               'date': '2023-01-01',
#               'reviewer_id': '51483096',
#               'reviewer_name': 'Cátia'},
#              'Great stay. The perfect house with the perfect service. We did a '
#              'last minute booking and everything went smooth. Everything was '
#              'very clean and the comunication was perfect. The house is '
#              'incredibly luxorious and fully equppied. Highly recommended',
#              {'_id': '256178235',
#               'comments': 'Great stay. The perfect house with the perfect '
#                           'service. We did a last minute booking and '
#                           'everything went smooth. Everything was very clean '
#                           'and the comunication was perfect. The house is '
#                           'incredibly luxorious and fully equppied. Highly '
#                           'recommended',
#               'date': datetime.datetime(2018, 4, 22, 4, 0),
#               'listing_id': '13574006',
#               'reviewer_id': '20775242',
#               'reviewer_name': 'Filipe'}]}

# %% [markdown]
# ### **Question 14** Add New Metric and Calculate Average

# %%
# 14) Add a new review metric called 'x_factor' with a score of 10. 
#     Show that the average score across all metrics is correctly calculated for this listing, using the previously developed query.

# 14. Add x_factor metric and calculate average
start_time = time.time()

# Add new metric
db.listingsAndReviews_HW2.update_one(
    {"_id": "20000000"},
    {"$set": {"review_scores_x_factor": 10}}
)

# Query with dynamic review_scores_* fields (from Query 9)
pipeline = [
    # Match the specific property
    {"$match": {"_id": "20000000"}},
    # Convert all document fields to an array of key-value pairs
    {"$project": {
        "all_fields": {"$objectToArray": "$$ROOT"}
    }},
    # Unwind the array to process each field
    {"$unwind": "$all_fields"},
    # Filter for fields starting with 'review_scores_'
    {"$match": {
        "all_fields.k": {"$regex": "^review_scores_"}
    }},
    # Project the score values, handling nulls
    {"$project": {
        "_id": 0,
        "Metric": "$all_fields.k",
        "Score": {"$ifNull": ["$all_fields.v", 0]}  # Default to 0 if null
    }},
    # Group to calculate the average across all metrics
    {"$group": {
        "_id": None,
        "AvgScore": {"$avg": "$Score"}
    }},
    # Project the final output with rounding
    {"$project": {
        "_id": 0,
        "AvgScore": {"$round": ["$AvgScore", 1]}
    }}
]

result = list(db.listingsAndReviews_HW2.aggregate(pipeline))
execution_time = time.time() - start_time

# Output
pprint(result)
pprint(f"Execution time: {execution_time:.4f} seconds")
# Out:
# [{'AvgScore': 10.0}]
# 'Execution time: 0.0043 seconds'

# %% [markdown]
# <div class="alert alert-block alert-danger">
#
# #### **ERRADO!**
#
# - Acho que não bem isto que ela quer! Temos de ver melhor, mas diria que na ***Question 9*** temos de criar uma função logo que calcule a média de todos os valores dos subdocumentos **`REVIEW SCORES`** sem os definir concretamente e agora acrescentar um novo valor e ver se a média é calculada corretamente
#
# </div>

# %% [markdown]
# ---

# %% [markdown]
# ## **📔 List of Potential Errors to Check and Correct**
#
# ### **1. Inconsistent Data Types**
#
# - **Fields**: `price`, `security_deposit`, `accommodates`, etc.
# - **🌋 Issue**: Might be stored as strings (e.g., `"$100.00"`, `"300"`) or numbers (`100.0`, `300`).
# - **🔍 Check**: Ensure `price`, `security_deposit`, `accommodates`, etc., are consistently typed.
#
# ### **2. Missing or Null Fields**
#
# - **Fields**: `security_deposit`, `review_scores_*`, `transactions`
# - **🌋 Issue**: Might be missing in some documents, leading to unexpected results.
# - **🔍 Check**: Identify missing fields and decide on defaults (e.g., `0` for `security_deposit`).
#
#
# ### **3. Transactions Mismatches**
#
# - **🌋 Issue**: If `transactions.transactions` exists, some entries might not belong to the listing.
# - **🔍 Check**: Verify each transaction’s context if linked to listings (though `sample_airbnb` doesn’t natively include this field).
#
# ### **4. Unnecessary Duplication**
#
# - **🌋 Issue**: Duplicate listings (same `_id`) or hosts (same `host_id` with different `host_name`) could skew counts.
# - **🔍 Check**: Look for duplicate `_id` or redundant host entries.
#
# ### **5. Case Sensitivity in Strings**
#
# - **Fields**: Amenities like `"Waterfront"` vs. `"waterfront"` or `"Dishwasher"` vs. `"dishwasher"`
# - **🌋 Issue**: Cause mismatches in `$all` filters.
# - **🔍 Check**: Standardize case in amenities (e.g., all lowercase).
#
# ### **6. Outliers or Invalid Values**
#
# - **Fields**: Extreme values in `price` (e.g., `$50,000`) or `accommodates` (e.g., `100`) or metrics like `review_scores_*`.
# - **🌋 Issue**: Might distort averages or differences.
# - **🔍 Check**: Identify and cap/filter outliers (e.g., `price > 10000` or `review_scores_* > 10`).
#
#
# ### **7. Date Format Inconsistencies**
#
# - **Fields**: If `transactions.transactions.date` exists, dates might vary (e.g., `"2008-01-01"` vs. `"01/01/2008"`) or be invalid.
# - **🌋 Issue**: Could break `$match`.
# - **🔍 Check**: Standardize date strings or convert to `ISODate`.
#
# ### **8. Array vs. String Fields (Specific to `transit`)**
#
# - **Fields**: `transit` might be a string like `"Bus • Subway • Train"` instead of an array `["Bus", "Subway", "Train"]`.
# - **🌋 Issue**: Complicates queries.
# - **🔍 Check**: Confirm if `transit` is always split by `" • "`, then convert to an array, but verify exceptions (e.g., commas, newlines).
#
# ### **9. Nested Field Assumptions**
#
# - **🌋 Issue**: Queries assume nested structures like `transactions.transactions` or `reviews.reviewer_name`, which might not exist or be misnamed.
# - **🔍 Check**: Validate field paths (e.g., `transactions` might just be `transactions`, not nested).
#
# ### **10. Inconsistent Units - Zero or Negative Values**
#
# - **Fields**: `accommodates` as `0` could cause division errors; negative `price` or `security_deposit` might be data entry errors.
# - **🌋 Issue**: Could lead to logical errors in calculations.
# - **🔍 Check**: Ensure `accommodates > 0`, `price >= 0`, etc.

# %% [markdown]
# ---

# %% [markdown]
# ### **Código**

# %% [markdown]
# #### **1. Inconsistent Data Types**

# %%
# 1. Inconsistent Data Types

# Check: Identify fields with mixed types using aggregation
numeric_fields = ["price", "security_deposit", "accommodates", "maximum_nights"]
for field in numeric_fields:
    pipeline = [
        {"$match": {field: {"$exists": True}}},
        {"$group": {
            "_id": {"$type": f"${field}"},
            "count": {"$sum": 1}
        }}
    ]
    type_counts = list(db.listingsAndReviews_HW2.aggregate(pipeline))
    print(f"Field {field} has types:")
    pprint(type_counts)
# Out:
# Field price has types:
# [{'_id': 'double', 'count': 1}, {'_id': 'decimal', 'count': 5555}]
# Field security_deposit has types:
# [{'_id': 'decimal', 'count': 3471}]
# Field accommodates has types:
# [{'_id': 'int', 'count': 5555}]
# Field maximum_nights has types:
# [{'_id': 'string', 'count': 5555}]

# %%
# # Resolve: Convert strings to numbers
# print("Resolving data type inconsistencies...")
# for doc in db.listingsAndReviews_HW2.find({"$or": [
#     {"price": {"$type": "string"}},
#     {"security_deposit": {"$type": "string"}},
#     {"maximum_nights": {"$type": "string"}}
# ]}):
#     update = {}
#     if isinstance(doc.get("price"), str):
#         update["price"] = float(doc["price"].replace("$", "").replace(",", ""))
#     if isinstance(doc.get("security_deposit"), str):
#         update["security_deposit"] = float(doc["security_deposit"].replace("$", "").replace(",", ""))
#     if isinstance(doc.get("maximum_nights"), str):
#         update["maximum_nights"] = int(doc["maximum_nights"])
#     if update:
#         db.listingsAndReviews_HW2.update_one({"_id": doc["_id"]}, {"$set": update})

# %%
# # Confirm: Verify all are numeric
# print("Confirming data types after cleanup...")
# for field in numeric_fields:
#     pipeline = [
#         {"$match": {field: {"$exists": True}}},
#         {"$group": {
#             "_id": {"$type": f"${field}"},
#             "count": {"$sum": 1}
#         }}
#     ]
#     type_counts_after = list(db.listingsAndReviews_HW2.aggregate(pipeline))
#     non_numeric = sum(tc["count"] for tc in type_counts_after if tc["_id"] not in ["double", "int", "decimal"])
#     print(f"Field {field} has {non_numeric} non-numeric values after cleanup")
#     pprint(type_counts_after)

# %% [markdown]
# ---

# %% [markdown]
# #### **2. Missing or Null Fields**

# %%
# 2. Missing or Null Fields

# Check: Count documents with missing fields
missing_counts = {
    "security_deposit": db.listingsAndReviews_HW2.count_documents({"security_deposit": {"$exists": False}}),
    "review_scores_*": db.listingsAndReviews_HW2.count_documents({"review_scores_rating": {"$exists": False}}),
    "transactions": db.listingsAndReviews_HW2.count_documents({"transactions": {"$exists": False}})
}
pprint(missing_counts)
# Out:
# {'review_scores_*': 1475, 'security_deposit': 2085, 'transactions': 1}

# %%
# # Resolve: Set defaults for missing fields
# db.listingsAndReviews_HW2.update_many({"security_deposit": {"$exists": False}}, {"$set": {"security_deposit": 0.0}})
# db.listingsAndReviews_HW2.update_many({"review_scores_rating": {"$exists": False}}, {"$set": {"review_scores_rating": 0}})

# %%
# # Confirm: Verify no missing fields
# updated_counts = {
#     "security_deposit": db.listingsAndReviews_HW2.count_documents({"security_deposit": {"$exists": False}}),
#     "review_scores_rating": db.listingsAndReviews_HW2.count_documents({"review_scores_rating": {"$exists": False}})
# }
# pprint(updated_counts)

# %% [markdown]
# ---

# %% [markdown]
# #### **3. Transactions Mismatches**

# %%
# 3. Transactions Mismatches

# Check: Count documents with transactions (assuming nested structure)
trans_count = db.listingsAndReviews_HW2.count_documents({"transactions.transactions": {"$exists": True}})
print(f"Documents with transactions.transactions: {trans_count}")
# Out:
# Documents with transactions.transactions: 5555

# %%
# # Resolve: Hypothetical validation (if listing_id exists in transactions)
# if trans_count > 0:
#     for doc in db.listingsAndReviews_HW2.find({"transactions.transactions": {"$exists": True}}):
#         valid_transactions = [t for t in doc["transactions"]["transactions"] if "listing_id" not in t or t["listing_id"] == doc["_id"]]
#         if len(valid_transactions) < len(doc["transactions"]["transactions"]):
#             db.listingsAndReviews_HW2.update_one({"_id": doc["_id"]}, {"$set": {"transactions.transactions": valid_transactions}})

# %%
# # Confirm: Recheck transactions
# if trans_count > 0:
#     invalid_trans = sum(1 for doc in db.listingsAndReviews_HW2.find({"transactions.transactions": {"$exists": True}})
#                         if any("listing_id" in t and t["listing_id"] != doc["_id"] for t in doc["transactions"]["transactions"]))
#     print(f"Invalid transactions after cleanup: {invalid_trans}")
# else:
#     print("No transactions field found in dataset")

# %% [markdown]
# ---

# %% [markdown]
# #### **4. Unnecessary Duplication**

# %%
# 4. Unnecessary Duplication

# Check: Identify duplicate _id
pipeline = [
    {"$group": {"_id": "$_id", "count": {"$sum": 1}, "ids": {"$push": "$$ROOT._id"}}},
    {"$match": {"count": {"$gt": 1}}}
]
duplicates = list(db.listingsAndReviews_HW2.aggregate(pipeline))
pprint(f"Found {len(duplicates)} duplicate _id groups")
# Out:
# 'Found 0 duplicate _id groups'

# %%
# # Resolve: Remove duplicates, keep first
# for dup in duplicates:
#     ids_to_remove = dup["ids"][1:]
#     db.listingsAndReviews_HW2.delete_many({"_id": {"$in": ids_to_remove}})

# %%
# # Confirm: Verify no duplicates
# duplicates_after = list(db.listingsAndReviews_HW2.aggregate(pipeline))
# print(f"Duplicates remaining: {len(duplicates_after)}")

# %% [markdown]
# ---

# %% [markdown]
# #### **5. Case Sensitivity in Strings**

# %%
# 5. Case Sensitivity in Strings

# Check: Sample amenities with mixed case
sample_amenities = db.listingsAndReviews_HW2.distinct("amenities", {"amenities": {"$exists": True}})
print(f"Sample amenities (first 5): {sample_amenities[:5]}")
# Out:
# Sample amenities (first 5): ['', '24-hour check-in', 'Accessible-height bed', 'Accessible-height toilet', 'Air conditioning']

# %%
# # Resolve: Standardize to lowercase
# for doc in db.listingsAndReviews_HW2.find({"amenities": {"$exists": True}}):
#     standardized_amenities = [amenity.lower() for amenity in doc["amenities"]]
#     db.listingsAndReviews_HW2.update_one({"_id": doc["_id"]}, {"$set": {"amenities": standardized_amenities}})

# %%
# # Confirm: Verify all lowercase
# mixed_case = db.listingsAndReviews_HW2.count_documents({"amenities": {"$elemMatch": {"$regex": "[A-Z]"}}})
# print(f"Amenities with uppercase after cleanup: {mixed_case}")

# %% [markdown]
# ---

# %% [markdown]
# #### **6. Outliers or Invalid Values**

# %%
# 6. Outliers or Invalid Values

# Check: Identify extreme values for price and accommodates
outliers = {
    "price": {
        "max": db.listingsAndReviews_HW2.count_documents({"price": {"$gt": 10000}}),
        "min": db.listingsAndReviews_HW2.count_documents({"price": {"$lt": 0}})
    },
    "accommodates": {
        "max": db.listingsAndReviews_HW2.count_documents({"accommodates": {"$gt": 50}}),
        "min": db.listingsAndReviews_HW2.count_documents({"accommodates": {"$lte": 0}})
    }
}

# Check: Dynamically identify and check all review_scores_* fields
pipeline = [
    # Convert all document fields to key-value pairs
    {"$project": {"all_fields": {"$objectToArray": "$$ROOT"}}},
    # Unwind the array
    {"$unwind": "$all_fields"},
    # Filter for review_scores_* fields
    {"$match": {"all_fields.k": {"$regex": "^review_scores_"}}},
    # Group by field name to count outliers
    {"$group": {
        "_id": "$all_fields.k",
        "max_outliers": {"$sum": {"$cond": [{"$gt": ["$all_fields.v", 10]}, 1, 0]}},
        "min_outliers": {"$sum": {"$cond": [{"$lt": ["$all_fields.v", 0]}, 1, 0]}}
    }}
]
review_scores_outliers = {doc["_id"]: {"max": doc["max_outliers"], "min": doc["min_outliers"]} 
                          for doc in db.listingsAndReviews_HW2.aggregate(pipeline)}

# Combine results
outliers.update({"review_scores": review_scores_outliers})
print("Outliers and invalid values before cleanup:")
pprint(outliers)
# Out:
# Outliers and invalid values before cleanup:
# {'accommodates': {'max': 0, 'min': 0},
#  'price': {'max': 6, 'min': 0},
#  'review_scores': {'review_scores_checkin': {'max': 0, 'min': 0},
#                    'review_scores_cleanliness': {'max': 0, 'min': 0},
#                    'review_scores_communication': {'max': 0, 'min': 0},
#                    'review_scores_location': {'max': 0, 'min': 0},
#                    'review_scores_rating': {'max': 4081, 'min': 0},
#                    'review_scores_value': {'max': 0, 'min': 0},
#                    'review_scores_x_factor': {'max': 0, 'min': 0}}}

# %%
# # Resolve: Cap/fix outliers
# print("Resolving outliers...")
# db.listingsAndReviews_HW2.update_many({"price": {"$gt": 10000}}, {"$set": {"price": 10000.0}})
# db.listingsAndReviews_HW2.update_many({"price": {"$lt": 0}}, {"$set": {"price": 0.0}})
# db.listingsAndReviews_HW2.update_many({"accommodates": {"$gt": 50}}, {"$set": {"accommodates": 50}})
# db.listingsAndReviews_HW2.update_many({"accommodates": {"$lte": 0}}, {"$set": {"accommodates": 1}})

# # Fix review_scores_* fields dynamically
# for field in review_scores_outliers.keys():
#     db.listingsAndReviews_HW2.update_many({field: {"$gt": 10}}, {"$set": {field: 10}})
#     db.listingsAndReviews_HW2.update_many({field: {"$lt": 0}}, {"$set": {field: 0}})

# %%
# # Confirm: Recheck outliers after cleanup
# outliers_after = {
#     "price": {
#         "max": db.listingsAndReviews_HW2.count_documents({"price": {"$gt": 10000}}),
#         "min": db.listingsAndReviews_HW2.count_documents({"price": {"$lt": 0}})
#     },
#     "accommodates": {
#         "max": db.listingsAndReviews_HW2.count_documents({"accommodates": {"$gt": 50}}),
#         "min": db.listingsAndReviews_HW2.count_documents({"accommodates": {"$lte": 0}})
#     }
# }

# pipeline_after = [
#     {"$project": {"all_fields": {"$objectToArray": "$$ROOT"}}},
#     {"$unwind": "$all_fields"},
#     {"$match": {"all_fields.k": {"$regex": "^review_scores_"}}},
#     {"$group": {
#         "_id": "$all_fields.k",
#         "max_outliers": {"$sum": {"$cond": [{"$gt": ["$all_fields.v", 10]}, 1, 0]}},
#         "min_outliers": {"$sum": {"$cond": [{"$lt": ["$all_fields.v", 0]}, 1, 0]}}
#     }}
# ]
# review_scores_outliers_after = {doc["_id"]: {"max": doc["max_outliers"], "min": doc["min_outliers"]} 
#                                 for doc in db.listingsAndReviews_HW2.aggregate(pipeline_after)}

# outliers_after.update({"review_scores": review_scores_outliers_after})
# print("Outliers and invalid values after cleanup:")
# pprint(outliers_after)

# %% [markdown]
# ---

# %% [markdown]
# #### **7. Date Format Inconsistencies**

# %%
# 7. Date Format Inconsistencies
print("Checking date format inconsistencies...")

# Check: Verify if transaction dates are consistently formatted

# Collect all date types and sample values
pipeline = [
    {"$match": {"transactions.transactions.date": {"$exists": True}}},
    {"$unwind": "$transactions.transactions"},
    {"$group": {
        "_id": {"$type": "$transactions.transactions.date"},
        "count": {"$sum": 1},
        "samples": {"$push": "$transactions.transactions.date"}
    }}
]
date_types = list(db.listingsAndReviews_HW2.aggregate(pipeline))

print("Transaction date types and counts:")
for dt in date_types:
    type_name = dt["_id"]
    count = dt["count"]
    samples = dt["samples"][:5]  # Limit to 5 samples
    print(f"Type: {type_name}, Count: {count}, Samples: {samples}")

# Check consistency
if len(date_types) == 1:
    print(f"All {date_types[0]['count']} transaction dates are consistently type: {date_types[0]['_id']}")
else:
    print("Inconsistent date formats detected!")
    pprint(date_types)
# Out:
# Checking date format inconsistencies...
# Transaction date types and counts:
# Type: date, Count: 311093, Samples: [datetime.datetime(2008, 8, 12, 0, 0), datetime.datetime(1999, 3, 9, 0, 0), datetime.datetime(2016, 6, 15, 0, 0), datetime.datetime(2015, 12, 17, 0, 0), datetime.datetime(2015, 2, 3, 0, 0)]
# All 311093 transaction dates are consistently type: date

# %%
# # Resolve: Convert to consistent YYYY-MM-DD string format (if desired)
# print("Resolving date formats to YYYY-MM-DD strings...")
# for doc in db.listingsAndReviews_HW2.find({"transactions.transactions.date": {"$exists": True}}):
#     updated_transactions = []
#     for t in doc["transactions"]["transactions"]:
#         if isinstance(t["date"], datetime):  # If datetime (ISODate)
#             t["date"] = t["date"].strftime("%Y-%m-%d")
#         elif isinstance(t["date"], str):  # If string, try parsing and standardizing
#             for fmt in ("%Y-%m-%d", "%d/%m/%Y", "%m/%d/%Y"):
#                 try:
#                     t["date"] = datetime.strptime(t["date"], fmt).strftime("%Y-%m-%d")
#                     break
#                 except ValueError:
#                     continue
#         updated_transactions.append(t)
#     db.listingsAndReviews_HW2.update_one({"_id": doc["_id"]}, {"$set": {"transactions.transactions": updated_transactions}})

# %%
# # Confirm: Verify all dates are now strings in YYYY-MM-DD format
# pipeline_confirm = [
#     {"$match": {"transactions.transactions.date": {"$exists": True}}},
#     {"$unwind": "$transactions.transactions"},
#     {"$match": {"transactions.transactions.date": {"$not": {"$regex": "^\\d{4}-\\d{2}-\\d{2}$"}}}},
#     {"$count": "inconsistent"}
# ]
# inconsistent = list(db.listingsAndReviews_HW2.aggregate(pipeline_confirm))
# inconsistent_count = inconsistent[0]["inconsistent"] if inconsistent else 0
# print(f"Inconsistent dates after cleanup (not YYYY-MM-DD): {inconsistent_count}")

# %% [markdown]
# ---

# %% [markdown]
# #### **8. Array vs. String Fields (Specific to `transit`)**

# %%
# 8. Array vs. String Fields (Specific to transit)
print("Checking transit field...")

# Check: Identify string vs array and separators using aggregation
pipeline = [
    {"$match": {"transit": {"$exists": True}}},
    {"$group": {
        "_id": {"$type": "$transit"},
        "count": {"$sum": 1},
        "samples": {"$push": "$transit"}
    }}
]
transit_types = list(db.listingsAndReviews_HW2.aggregate(pipeline))
print("Transit field types and counts:")
for tt in transit_types:
    type_name = tt["_id"]
    count = tt["count"]
    samples = tt["samples"][:5]
    print(f"Type: {type_name}, Count: {count}, Samples: {samples}")

# Check separators for string transit fields
transit_variations = set()
for doc in db.listingsAndReviews_HW2.find({"transit": {"$type": "string"}}, limit=100):  # Increased limit for better coverage
    transit_str = doc["transit"]
    if " • " in transit_str:
        transit_variations.add(" • ")
    elif ", " in transit_str:
        transit_variations.add(", ")
    elif "\n" in transit_str:
        transit_variations.add("\n")
    else:
        transit_variations.add("unknown")
print(f"Transit separator variations in string fields: {transit_variations}")
# Out:
# Checking transit field...
# Transit field types and counts:
# Type: string, Count: 5555, Samples: ['Transport: • Metro station and S. Bento railway 5min; • Bus stop a 50 meters; • Lift Guindais (Funicular) 50 meters; • Tuc Tuc-to get around the city; • Buses tourist; • Cycling through the marginal drive; • Cable car in Gaia, overlooking the Port (just cross the bridge).', 'Easy access to transport (bus, taxi, car) and easy free parking around. Very close to Gávea, Leblon, Ipanema, Copacabana and Botafogo.', 'Honolulu does have a very good air conditioned bus system.', '', '']
# Transit separator variations in string fields: {', ', 'unknown', ' • '}

# %%
# # Resolve: Convert string transit to arrays
# print("Converting string transit to arrays...")
# for doc in db.listingsAndReviews_HW2.find({"transit": {"$type": "string"}}):
#     transit_str = doc["transit"].strip()
#     separator = " • " if " • " in transit_str else ", " if ", " in transit_str else "\n" if "\n" in transit_str else None
#     if separator:
#         transit_array = [item.strip() for item in transit_str.split(separator) if item.strip()]
#         db.listingsAndReviews_HW2.update_one({"_id": doc["_id"]}, {"$set": {"transit": transit_array}})
#     else:
#         print(f"Warning: No clear separator in transit for _id {doc['_id']}: {transit_str}")

# %%
# # Confirm: Verify all transit fields are arrays
# pipeline_confirm = [
#     {"$match": {"transit": {"$exists": True}}},
#     {"$group": {
#         "_id": {"$type": "$transit"},
#         "count": {"$sum": 1}
#     }}
# ]
# transit_types_after = list(db.listingsAndReviews_HW2.aggregate(pipeline_confirm))
# print("Transit field types after cleanup:")
# pprint(transit_types_after)
# string_count = sum(tt["count"] for tt in transit_types_after if tt["_id"] == "string")
# print(f"String transit fields remaining: {string_count}")

# %% [markdown]
# ---

# %% [markdown]
# #### **9. Nested Field Assumptions**

# %%
# 9. Nested Field Assumptions

# Check: Validate nested paths
nested_counts = {
    "transactions.transactions": db.listingsAndReviews_HW2.count_documents({"transactions.transactions": {"$exists": True}}),
    "reviews.reviewer_name": db.listingsAndReviews_HW2.count_documents({"reviews.reviewer_name": {"$exists": True}})
}
pprint(nested_counts)
# Out:
# {'reviews.reviewer_name': 3924, 'transactions.transactions': 5555}

# %%
# # Resolve: Flatten if doubly nested (e.g., transactions.transactions -> transactions)
# for doc in db.listingsAndReviews_HW2.find({"transactions.transactions": {"$exists": True}}):
#     db.listingsAndReviews_HW2.update_one({"_id": doc["_id"]}, {"$set": {"transactions": doc["transactions"]["transactions"]}})

# %%
# # Confirm: Recheck nested fields
# flattened_counts = {
#     "transactions.transactions": db.listingsAndReviews_HW2.count_documents({"transactions.transactions": {"$exists": True}}),
#     "transactions": db.listingsAndReviews_HW2.count_documents({"transactions": {"$exists": True, "$not": {"$type": "object"}}})
# }
# pprint(flattened_counts)

# %% [markdown]
# ---

# %% [markdown]
# #### **10. Inconsistent Units - Zero or Negative Values**

# %%
# 10. Inconsistent Units - Zero or Negative Values

# Check: Count invalid values
invalid_counts = {
    "accommodates <= 0": db.listingsAndReviews_HW2.count_documents({"accommodates": {"$lte": 0}}),
    "price < 0": db.listingsAndReviews_HW2.count_documents({"price": {"$lt": 0}}),
    "security_deposit < 0": db.listingsAndReviews_HW2.count_documents({"security_deposit": {"$lt": 0}})
}
pprint(invalid_counts)
# Out:
# {'accommodates <= 0': 0, 'price < 0': 0, 'security_deposit < 0': 0}

# %%
# # Resolve: Fix invalid values
# db.listingsAndReviews_HW2.update_many({"accommodates": {"$lte": 0}}, {"$set": {"accommodates": 1}})
# db.listingsAndReviews_HW2.update_many({"price": {"$lt": 0}}, {"$set": {"price": 0.0}})
# db.listingsAndReviews_HW2.update_many({"security_deposit": {"$lt": 0}}, {"$set": {"security_deposit": 0.0}})

# %%
# # Confirm: Verify no invalid values
# invalid_counts_after = {
#     "accommodates <= 0": db.listingsAndReviews_HW2.count_documents({"accommodates": {"$lte": 0}}),
#     "price < 0": db.listingsAndReviews_HW2.count_documents({"price": {"$lt": 0}}),
#     "security_deposit < 0": db.listingsAndReviews_HW2.count_documents({"security_deposit": {"$lt": 0}})
# }
# pprint(invalid_counts_after)

# %% [markdown]
# ---
